# %%
from dotenv import load_dotenv
import os

load_dotenv()
token = os.getenv("API_KEY")

# %% [markdown]
# ### 2. Get the Review Corpus

# %%
import requests

def fetch_reviews(token , number_of_reviews = 5, page_num = 1):
    url = "https://data.g2.com/api/v1/survey-responses"
    headers = {
        "Authorization": f"Token token={token}",
        "Content-Type": "application/vnd.api+json"
    }

    
    params = {

        "page[size]": f"{number_of_reviews}",
        "page[number]": f"{page_num}"  
    }

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()
        return data['data']
    else:
        print(f"Error: {response.status_code} - {response.text}")
        
        return None


response = fetch_reviews(token, 100, 1)

# %% [markdown]
# ### 3. Preprocess the Review Corpus

# %%
from datetime import datetime

def change_to_dd_mm_yyyy(rfc3339_date):
    dt_object = datetime.fromisoformat(rfc3339_date)
    return dt_object.strftime('%d%m%Y')

def create_review_dictionary(reviews):
    review_dict = {}
    for review in reviews:
        attributes = review["attributes"]
        review_id = review["id"]
        try:
            review_dict[review_id] = {
                "ease_of_doing_business_with": attributes["secondary_answers"]["ease_of_doing_business_with"]["value"] if "ease_of_doing_business_with" in attributes["secondary_answers"] else None,
                "country_name": attributes["country_name"],
                "votes_up": attributes["votes_up"],
                "votes_down": attributes["votes_down"],
                "votes_total": attributes["votes_total"],
                "star_rating": attributes["star_rating"],
                "time": change_to_dd_mm_yyyy(attributes["submitted_at"]),
                "likes": attributes["comment_answers"]["love"]["value"],
                "dislikes": attributes["comment_answers"]["hate"]["value"]
            }
        except:
            pass
    return review_dict

review_dict = create_review_dictionary(response)

# %%
likes_dict = {}


for review_id, review in review_dict.items():
    likes = review["likes"]
    dislikes = review["dislikes"]
    if likes in likes_dict:
        likes_dict[review_id].append(likes)
    else:
        likes_dict[review_id] = [likes]

# %% [markdown]
# ### 4. Name Imputation

# %%
import spacy

nlp = spacy.load("en_core_web_lg")

def change_name(sentence : str):
    doc = nlp(sentence)
    replaced_sentence = sentence
    for entity in doc.ents:
        if entity.label_ == "PERSON" :
            replaced_sentence = replaced_sentence.replace(entity.text, "person")
        if entity.label_ == "ORG" :
            replaced_sentence = replaced_sentence.replace(entity.text, "organization")            
           

    return replaced_sentence

# %%
for review_id in likes_dict:
    for like in likes_dict[review_id]:
        likes_dict[review_id] = change_name(like)

# %%
likes_dict
# Out:
# {'18532': "organization has helped our customers publicly validate us to prospects and has helped us build pipeline and be considered for opportunities where we likely would not have been found otherwise. Also it has aided as a great validation point for customers in meetings and demo's as to our market profile and position.  It has helped us need less reference calls and enabled our customers to have a more open and valid place to voice their opinion on us.",
#  '67896': 'It showcases a wide range of vendors with unbiased and helpful reviews for evaluating solutions within your organization. This helps companies accelerate their marketing efforts and sales cycles when shared effectively. \r\n\r\nThe smart grid is also a really great way to show how your company is perceived in the market place.\r\n\r\nQuarterly reports are very detailed and are helpful overviews for companies trying to evaluate vendors. ',
#  '177131': 'Great way to build our brand in a new space, by leveraging user success. Also, person did a great job of helping us understand the value of the platform when we first started.',
#  '179859': "The end to end service and process has been the highlight to my experience. Advocately has ensured our success by assisting us with implementing our review campaigns. They've consistently optimised our process to achieve our goals.",
#  '179888': 'organization facilitates a continuous flow of great reviews of your product or service on the top review sites across the web. We have had excellent service and it is clear that organization is committed to getting the best results for their clients. They have a vision for this space that I have not seen before, and it is a welcome innovation. ',
#  '182325': 'It works exactly as intended. Promoters get pro-active outreach for review requests in a way that is not over-the-top. The team at advocately have made themselves available at every step in the onboarding journey as well. Great service',
#  '182489': 'We were previously using engagement as a criteria for requesting a review (which we were doing manually). The blend of using organization along with the automation organization provides means we are getting a higher volume of higher quality reviews for less work.',
#  '183103': 'Getting reviews is an integral part of any (online) business these days but the process can be very time consuming and hard. With Advocately the entire process is automated which is a huge work load lifted. After the initial setup you just let the system do the work for you, the support is great and the product works like a charm. I can highly recommend Advocately to anyone who relies on reviews! ',
#  '183130': 'We are getting our promoters to write reviews online and refer their friends at an extremely high rate!  We can link the results from this back to revenue.',
#  '184048': 'Advocately helped us reach out to our top promoters and helped build out our reviews across our different platforms.',
#  '184054': 'Being in organization, it is extremely important to know how your customers feel about your product and service and getting constant feedback is absolutely necessary. With Advocately, we get an all-in-one platform that gives us the data we need to help us engage better with our clients.',
#  '188630': 'Advocately helps us to automate the process of reaching out to get reviews from customers that love our product. Another feature I like is the ability to explore which users are our net promoters. This is much potential to continuously refine our market segments using this tool.',
#  '188638': 'Advocately has provided us on the best insights to run our organization campaign and to generate the reviews that are essential for customer advocacy in the SaaS solutions industry. \r\n\r\nThey identified what works best for us in terms of getting a favorable response rate from the organization surveys and we really have moved forward from there.',
#  '190023': 'organization is extremely easy to use. person was very helpful in setting us up on the platform. The integration and set up was quick, templates were provided to get the best result. Everything is engineered for our success, i am very happy with the platform. ',
#  '199474': 'As a organization Manager I am responsible for crafting and executing our advocate program. Perhaps the most challenging aspect of creating an advocate program is finding the advocates. organization has eliminated challenge. The advocates, through organization, came to me! Not only do I now have a growing list of advocates, but I am able to see exactly what they love about our software. This enables me to push feedback to the marketing, development, and customer success teams so that we can enhance what people love.\r\n\r\nAside from the actual product, person and person are amazing. Support, response times, and personality are all 10/10. You guys rock!',
#  '199488': 'The support, and the experience the organization founders bring in having done exactly what organization promises for a SaaS business just like ours. The offering is spot on, and simply works. ',
#  '199954': "I used to go through a lot of steps to get reviews. I was probably spending 5-6 hours a month to get reviews. There were so many manual steps and we would barely get any reviews out of it. It always felt worth it because our organization and reputation is very important to us. Now, with organization, I just set up campaigns and they take care of the rest. We initially tested it out on 40 users and within that we produced 20 reviews!!!!! The same subset of users would probably would have produced 2 or 3 reviews within my old process. \r\n\r\nAlso, the support has been amazing! person has extremely helpful at setting us up and guiding us through the onboarding process. He has been very flexible in the hours he has helped and I've always very quickly got a response to questions. ",
#  '201553': 'Advocately is very easy to use and we’ve received outstanding support from their team. It helped us understand our customer’s requirements better. We were able to see results in just a few months! ',
#  '202787': 'At person, we are new to organization and getting customer reviews on G2 Crowd. At first, I was concerned that it was going to be hard to get all these up and running manually, but organization has made getting setup a breeze for us.\r\n\r\nAnd within the first day of getting setup on organization, we ran our first organization survey, got dozens of responses, which organization then automatically reached out to - and we got our first 5 star review on that day itself.\r\n\r\nSupport from organization has been top-notch, and he was very patient and helpful in walking us through the entire process from start to finish.',
#  '276255': "Tells you what categories a company falls into, who they're competitors are, and what it's strengths/weaknesses are in the market place by way of customer reviews as well as their own analysis.",
#  '277667': 'G2Crowd is a great resource in understanding comparative reviews when it comes to understanding customer satisfaction, competitor analysis and the benefits to using certain solutions.',
#  '277668': 'G2Crowd enables us to be able to show how well our product works, how customers view us and close more deals because of it.',
#  '277669': "organization crowd has allowed us to let our customers speak directly to our customers. As a sales person, I don't want to constantly be bogging down my customers with asking them to give a reference for prospects who aren't far into the sales funnel. organization crowd allows me to provide referrals to prospects, without having to annoy my customers, before my prospects are fully qualified. I also love the full transparency required by organization, as my customers can trust that the information they are getting is trustworthy.",
#  '280373': "The reviews, especially the fact they include 'what do you dislike' as well as 'what do you like'.  It gives a much more rounded picture.  The grids are useful, so too the ability to run grids based on user segment.  I also like the side-by-side comparisons.",
#  '288758': 'Easy to setup, organization and good pricing!  ',
#  '289187': "organization's platform is a great way to drive advocacy from your customers. Asking clients to review your product is a sure way to know how they actually feel about you, and in return you're empowering sales with a easy way to reach our for references pre-sales.",
#  '293991': "This is my second time working with organization and I'm impressed by recent enhancements to the platform, particularly the buyer intent activity data and the intuitiveness of the backend. Our sales team is really excited to find accounts with potential need for our solution that they wouldn't necessarily have uncovered otherwise.\r\n\r\nI also appreciate the organization team, they are easy to work with, helpful, thorough, and dedicated to making sure we get the most out of our investment.",
#  '296992': 'I like how easy it is to run reviews campaigns and leverage the tools in your listing to market you business. Have our listings on G2 Crowd has helped us tremendously in building trust and credibility with out prospects and close more business.',
#  '297223': 'person goes the extra mile . She is a huge help and a pleasure to work with. There is a real commitment on her part to help her clients succeed',
#  '297239': "We've received decent service pretty consistently. The online platform is easy enough to work through. Leads are just okay.",
#  '297426': 'Overall, I am very happy with G2 Crowd. We are able to drive high quality leads to our sales team. Our reps are also great, fast to respond and always helpful.',
#  '300311': "G2 Crowd's team is amazing to work with! They are always very responsive and are always proactively reaching out to make sure we get the best results of the programs we are running. You can't get a better organization than person! ",
#  '300948': 'G2Crowd has invested heavily in advertising their brand versus the other review sites.  As a result they have a much bigger quantity of reviews.  So it has traction now and people trust it to create a shortlist and to determine what others think.',
#  '300976': "G2 Crowd provides a very impartial and fully verified technology software review forum. The technology sections are well defined and nicely summarized.  Overall, it's very professional and you can actually count on the review provided since they can't be manipulated by the vendors.   Really like the way that we can embed the review widgets on our own website with links to our optimized landing page.  The environment provides a great user experience for visitors to our website and illustrates how open we are to input from our customers. The style of review presentation is also very easy for visitors to consume. It's similar to consumer based review sites, but with much higher data quality.  We count on the fact that prospects reading our reviews can trust the customer input.",
#  '302708': 'I really enjoy working with G2 Crowd for a few reasons, one of them being their customer support. The team at G2 Crowd has worked hand in hand with Certify to create custom content to better suit our needs and help position Certify stronger in the selling process. \r\n\r\nFrom a technology standpoint, I really value the competitive analysis aspect of G2 Crowd. The fact that a prospect can search and compare over 1,000 reviews on expense management in minutes and rank the top performing vendors is really invaluable. Having this organization-like review process for business software has allowed us to showcase our strengths against competitors and replace the traditional client referral process. ',
#  '305790': 'I originally signed up with G2 Crowd to generate awareness of our solution as they had the most product/ competitor reviews for our industry (PR tools and media targeting) and had a robust process to help you generate reviews for products. But I was blown away, when on top of awareness and SEO magic, G2 Crowd has also become a key source of sales leads for us. ',
#  '307360': 'The configuration and on-boarding process for a vendor is very straightforward, intuitive and yet comprehensive. I also like the experience provided by G2Crowd to users researching products. It is fluid and informational. ',
#  '309559': 'I like the clean look and feel of the website. They also have instant chat which is nice if you have a question that you need answered really quickly. The organization I have is knowledgeable, responsive and helpful.',
#  '320249': "I've appreciated the opportunity to get honest reviews from our customers. It's opened up the opportunity to hear their feedback and also showcase our value to prospects. \r\n\r\nAdditionally, I've loved the customer support I've gotten from person! He's always been incredibly helpful, friendly, honors his commitments, and holds me accountable for getting our campaign done!",
#  '329787': 'We are in a competitive marketplace and we rely on G2 Crowd to help us stand out from our competitors.  ',
#  '333833': 'I think the Customer Success Management team is really accessible and helpful when I have questions.',
#  '333931': "I've used organization now for over 3 years at different companies and we continue to utilize them as a trusted vendor because of the ability to gather feedback from clients quickly and easily. By running review campaigns we can uncover what areas of focus we need for our product and how to identify new advocates for our programs. The grid reports also help us stay relevant to our competitors and the marketplace.",
#  '334128': "It's a great resource if you're looking for honest reviews on a software solution. You can read through both the good and bad about a particular offering, so that you can walk into purchase decisions much better informed. ",
#  '334309': "Site is so easy to use - even for the most non-tech person like me! Also, G2 Crowd team is very responsive when you have questions or concerns and does their best to either fix the problem or get others from the extended team involved to resolve or come up with a viable and workable solution. One very nice capability is the widget tool. I love that it's embedded in the admin portal and it's super easy to understand and share. It's definitely something that I will use to help socialize the customer reviews. ",
#  '334965': "-Reading feedback from customers has been amazing!  We've been encouraged by how much people love person, and the reviews have had great ideas.\r\n\r\n-Also, our onboarding specialist person was helpful, friendly, flexible, and responsive. I always had the information I needed and we got off to a great start. ",
#  '335954': 'Based on SatisMeter NPS, organization absolutely person helped us double the number of positive reviews in organization for just 1 month. We love personal attitude and great service. The system is easy-to-use, we enjoy UX. We look forward to bringing new reviews about organization. Because review websites and reviews are one of the best traffic sources for us. ',
#  '336467': 'organization is a great sales and marketing resource for our company. It provides lead generation and content as well as an opportunity to harness genuine feedback from our customers. ',
#  '336576': 'I enjoy the ease of logging in and seeing how the pages I own are performing and doing. Navigating is straightforward.',
#  '336584': 'I love being able to reach out to person with any questions I have. I also love how many reports G2 Crowd offers related to rankings, usability, service, and support!',
#  '336667': "person has been a friendly and responsive rep . She's quick to make suggestions and help out with our different marketing options.  person has been awesome!\r\n\r\nThe reviews written on G2 Crowd are comprehensive and very useful for consumers. \r\n\r\nThey're growing their marketing tools, and we're trying a few of them out. \r\n\r\nI like the backend options for building out our profile to best educate our prospects on the value of our service. You can upload videos, FAQs, and key details about the software.  Their reporting features are relevant and accurate as well.\r\n\r\nLove their award badges as a great form of social proof.",
#  '336671': "It''s too easy for companies to post anonymous quotes from supposed customers.  Too many reviews are cliches.  organization offers us a legit third party system and the reviewers are all validated through organization.  ",
#  '336688': "I thoroughly enjoy the G2 Crowd tool.  It's very easy to use and navigate.  I recently set up close to 10 pages for my organization and everything was very seamless.",
#  '336718': 'Very simple to get started bringing in detailed reviews from happy customers, the team is always available to help out and come up with new ideas. ',
#  '336726': 'Everything on the site is streamlined and intuitive for both the user and the vendor. They offer lots of features to utilize as a vendor, and they have a lot of things that help you promote your page.',
#  '336856': '1. Overall good approach - good to collect customer feedback\r\n2. Most players seem to prefer G2Crowd',
#  '336870': 'Easy to work with. Review campaigns are a great way to get reviews kicked off. Accounts team is proactive in finding you ways to increase reviews and exposure. ',
#  '337033': 'The concept - customer reviews for B2B products.  The simplicity.  They are the leaders in this area.',
#  '337119': 'The depth of criteria that G2 Crowd puts together the reports are very granular and thorough. For an underdog brand like ourselves, this credibility was invaluable. The team was super helpful in helping navigate the product and strategize with execution on our end. ',
#  '337501': 'Creating a profile on G2 Crowd gives an opportunity to build a comprehensive overview of your product/service.',
#  '337728': 'we get leads from them. they also provide analytics on your page.',
#  '337902': 'The onboarding process went very smoothly. If we had a question or concern, organization onboarding staff answered  all emails and phone calls within the hour. The service we received was impeccable.',
#  '338568': 'I like the wealth of  info and tools for related to our product reviews. As well, organization handling of the campaign to acquire ouru reviews was smooth and simple.',
#  '339183': "G2 Crowd is an intelligent solution that's easy to use. Any busy software company will be able to get started quickly—and there is plenty of help along the way from the G2 Crowd team to optimize your listing.\r\n\r\nThe G2 Crowd review formatting is so much better than other platforms, set up in a way that encourages lengthy feedback. Reviews we see here from our happy customers are always super detailed and useful, giving us golden insights we can use for customer success, sales, and marketing intelligence.\r\n\r\nWe've been extremely impressed by the level of support from G2 Crowd. This likable team is with you every step of the way, because they truly care about your company's success.",
#  '339591': "organization offers a powerful medium for our software users to share their experience with the world.  We're able to differentiate ourselves and provide references to potential new customers prior to ever engaging with them.",
#  '341360': "Team is very personable and easy to talk to. The platform is simple enough to use in the back-end, everything is labeled clearly and I don't feel like I am lost looking for what I need.",
#  '341641': 'I love being able to contact person from G2 Crowd at any time about anything! She helps me fill out the profile and give me suggestions on how to take full advantage of it!',
#  '342331': 'The platform is very user friendly and the customer service are fast and responding back to question',
#  '345131': ' From an ender user\'s perfective  g2 crowd provides unbiased and "real world" facts for those  in the process of selecting a Saas product . From a organization,  the quality and consistency of leads we have received is  very much above average .',
#  '345742': "G2 Crowd provides an easy-to-use service that allows our customers to quickly create testimonials and describe their use. It's a great resource for prospective customers researching emergency notification software. We often use it in our email marketing to prospective customers.",
#  '346659': 'The reviews feature has helped us out in gaining credibility and increasing brand awareness.',
#  '347110': 'It provides our prospects and current clients a destination spot to to learn about person directly from our customers. ',
#  '348994': 'G2 Crowd is a great review platform that allow prospects to educate themselves about software by reading the experience of other users. We include review snippets on our Customers Success Stories website page and email campaigns. ',
#  '351531': 'Their customer service is excellent. No question goes unanswered for long. They always provide a prompt and thorough response.',
#  '354532': "G2 Crowd gets great traffic, even in my company's lesser known product category. By pushing the pageviews to organization via Zapier the entire sales and marketing team can easily get a sense of how many people are landing on our page every day. It's between 10-15. G2C isn't a huge source of demo requests, but the awareness from this website is good.\r\n\r\nCSMs are very responsive (thanks person!)",
#  '366147': 'Transparency of customer feedback to public channels. ',
#  '366910': "It makes our lives much easier and as they are verified users, its genuine.  There's nothing to hide, which promotes good partnership.  ",
#  '369501': 'Personally, I love the reports they generate which help us make key marketing idea decisions which we roll out on our sites each quarter.',
#  '370467': 'I like the analytics components. It’s quite interesting to see which companies are comparing us to which vendors.',
#  '371950': "The reporting functionality and insight into customer needs.\r\nThe ability to give customers and prospects insight into their peer's thoughts \r\nThe support I have received thus far.",
#  '372540': "organization is the best unfiltered and comprehensive platform to learn about strengths and weaknesses of various b2b tech in the market both established and contending.\r\n\r\nThe comparisons are also great because they turn unstructured written reviews into actionable and measurable data across a range of metrics.  This means a decision maker can choose to focus on overall ratings, specific features, or the various rich and qualitative reviews.\r\n\r\nWhat's more, all of this is based on validated profiles, so no fake reviews.\r\n\r\n",
#  '377146': "It's the age of the customer, let's face it. Which means as marketers we must embrace the voice of our customers to build brand and drive demand. G2Crowd organization not only allow us to manage a branded profile - host assets for download and offer various CTAs for lead gen purposes, but they also help in ensuring your company follows best practices when it comes to recruiting and leveraging reviews. In addition, they offer super valuable competitive comparison reports to help your sales team deposition the competition, shorten sales cycles and ultimately win more deals! Lastly, they've got a wealth of data that your marketing team can leverage for better intel and retargeting purposes. Also, kudos to person, our client manager, who has been stellar to work with -- smart and knows how to work with his clients to ensure they get the most impact out of their investment. ",
#  '377260': "G2Crowd is an essential customer touchpoint in our audience's evaluation and buying process. It allows us to invite our customers to review/promote us online where others are looking, we can brand our page and we can capture contact information of those interested in a solution like ours. And when we need our account manager is there to help!",
#  '378271': "I'm an admin for two products for my company. As a marketer, this platform is easy to manage, edit widgets, and pull from for my own use (social media, website promotions, email, etc). The user interface is clean, easy to navigate, and a great tool for our sales reps to use.\r\n\r\nThe customer service and sale reps have helped us make this an successful marketing campaign. Giving us great ideas to push these reviews in multiple ways. And THEY reach out to our customers for the reviews! I love when vendors help with heavy lifting. ",
#  '380575': "Makes it easy to generate more product reviews for our SaaS tool. It's very easy to setup and follows a logical process. Our tool is multi-language and this is easily supported with organization. ",
#  '380649': "The great custom on boarding by the account team has helped us set up a successful review campaign very fast.\r\n\r\nThis platform has added a new dimension to our demand gen and marketing programs. The unbiased review platform is a great tool for presenting our product to buyers in the research stage and educating them about our product.   \r\n\r\nIt's been a great way to gather customer feedback in a simple and trustworthy format, which makes it easier to share with new clients. Overall an amazing experience, and we have been thrilled to see how much our customers love the organization platform!\r\n\r\n",
#  '381519': 'G2 Crowd is a great platform to help promote customer advocacy and gather reviews from users. As a profile admin, its easy to update our page, add features, and invite our customers to submit their reviews.',
#  '396580': 'Working with person was the absolute best, he was insightful and very supportive as we looked for ways to increase the quantity and quality of our reviews in order to improve our online reputation.',
#  '415865': 'I love how the reviews are filtered and how well customers are featured. The ability to do direct compares against competitors is also a plus to see exactly where we are. ',
#  '419224': 'Works like a parallel website, generating brand awareness and leads',
#  '455401': 'Everyone is extremely helpful when it comes to any questions we may have. High response rate as well.',
#  '457279': 'G2Crowd has been invaluable to help build our referral program, and to help support our Sales team in the past. Reviews are quick and easy to fill out, and help foster customer advocacy.',
#  '457954': 'Advocately has heavily increased our online  customer reviews through  friendly effective campaigning. The set up was so simple,  their  integration specialist had us live after having had 1 call together.',
#  '457971': 'Sending personalised emails via gmail to our "promoter" customer base in the background with little input from us. ',
#  '474344': 'We are seeing great prospects and customers coming to G2Crowd for unbiased opinions and reviews that help SpringCM get off to a great start in a sales or upsell cycle.  For instance one of our largest deals closing this quarter will come from a prospect that was not engaged with us previously that went first to G2Crowd, then contacted us through www.springcm.com and signed for a multi-six figure initial deal value.   The business model of G2Crowd gives comfort in that the information was not paid for or biased in any way, which helps us greatly in the initial stages.',
#  '479059': 'My favorite feature is the comparison grid that allows prospects to see how we stack up against our competitors and the focused profile that we can send to prospects.',
#  '492019': '1.  Strong focus on review management.\r\n2.  Well thought-out process for maintaining authenticity.\r\n3.  Value-driven marketing platform which enhances PR and social proof. \r\n4. Strong support from the G2 crowd team.',
#  '515733': 'The peristance of the team to help my company acheive their objectives. G2 Crowd well unnderstands their roll and makes it their business to undersatand the product line(s) of their custoemrs.',
#  '519906': 'G2 Crowd provided the best onboarding experience compared to some of the other peer review sites I have used. Our dedicated account manager and implementation specialist worked with us through every step ensuring that we were leveraging all that G2 Crowd has to offer.',
#  '527085': "It's straightforward and easy to manage. The admin console for product pages is simple to use. There are a lot of great tools to leverage across marketing content and campaigns. And certainly not least, everyone in the company benefits from hearing directly from customers about what is and is not working for them.",
#  '534024': 'organization is a best-of-industry service that provides an awesome review of enterprise products and services.  It will save you at least half the time you would invest discovering this information on your own.'}

# %% [markdown]
# ### 5. Feature Extraction

# %%
import os
import requests

API_URL = "https://api-inference.huggingface.co/models/mistralai/Mistral-7B-Instruct-v0.2"

def get_headers(api_key):
    headers = {"Authorization": f"Bearer {api_key}"}
    return headers

def query(payload, api_key):
    headers = get_headers(api_key)
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

def extract_features(review, api_key):
    preprompt = "Here is a review : "
    endprompt = "List the features what user liked, give keyword or 2 word phrases only. Give the output in format features: feature1, feature2, feature3, ..."
    
    response = query({
        "inputs": preprompt + review + endprompt,
        "temperature": 0.9,
    }, api_key)
    
    return response

# Example usage:
API_KEY = os.getenv("HF_KEY4")  # Assuming you retrieve the API key from environment variables
review = "This product is amazing! I love it."
features = extract_features(review, API_KEY)
print(features)
# Out:
# [{'generated_text': 'Here is a review : This product is amazing! I love it.List the features what user liked, give keyword or 2 word phrases only. Give the output in format features: feature1, feature2, feature3, ...Reusable, Mini, Lightweight, Powerful, Charges quickly, Compact, Portable, Durable, Rechargeable, Long Lasting, Versatile, Affordable.\n\nFeatures: Compact, Portable, Lightweight, Rechargeable, Long Lasting, Versatile, Affordable, Powerful.'}]

# %%
features_dict = {}

for review_id in likes_dict:
    features_dict[review_id] = extract_features(likes_dict[review_id], API_KEY)

# %%
import json

# Your feature_dict should be populated as per your previous code

# Specify the file path where you want to save the JSON file
json_file_path = "feature_dict_lite.json"

# Write feature_dict to a JSON file
with open(json_file_path, "w") as json_file:
    json.dump(features_dict, json_file)

print("Feature dictionary lite saved as JSON successfully.")
# Out:
# Feature dictionary lite saved as JSON successfully.

# %%
copy_feature_dict = features_dict.copy()

# %%
for review_id in copy_feature_dict:
    review = copy_feature_dict[review_id][0]["generated_text"].lower()
    if review.find("feature1, feature2, feature3, ...") != -1:
        copy_feature_dict[review_id]= review[review.find("feature1, feature2, feature3, ...")+len("feature1, feature2, feature3, ..."):].strip()

# %%
for review_id in copy_feature_dict:
    review = copy_feature_dict[review_id]
    
    if review.find("features:") != -1:
        copy_feature_dict[review_id] = review[review.find("features:")+len("features:"):].strip()

# %%
for review_id in copy_feature_dict:
    # remove punctuations and escape sequences from the string and remove digits
    review = copy_feature_dict[review_id]
    review = review.replace("\n", "")
    review = review.replace("\r", "")
    review = review.replace(".", "")
    review = review.replace("\"", "")
    review = review.replace("\'", "")
    review = review.replace("/", "")
    review = review.replace("(", "")
    review = review.replace(")", "")
    review = review.replace("*", "")
    review = review.replace("-", "")
    review = review.replace(":", "")
    
    for letter in review:
        if letter.isdigit():
            review = review.replace(letter, "")
    
    copy_feature_dict[review_id] = review

# %%
for review_id in copy_feature_dict:
    review = copy_feature_dict[review_id].strip()
    review = review.split(",")
    
    sorted_review = sorted(review, key = len)
    
    
    for i in range(len(sorted_review)):
        feature = sorted_review[i].strip()
        
        if len(feature.split(" ")) > 3:
            feature = ""
        
        sorted_review[i] = feature
    
    copy_feature_dict[review_id] = sorted_review

# %%
for review_id in copy_feature_dict:
    print(copy_feature_dict[review_id])
# Out:
# ['position', 'open forum', 'market profile', 'reference calls', 'public validation', 'validation point', 'building pipeline']
# ['', 'mobile access', 'lead management', 'task management', 'team management', 'sales management', 'contact management', 'sales forecasting', 'project management', 'email communications', 'marketing automation integration', '']
# ['brand building', 'great start help', 'user success stories', 'valuable platform understanding']
# ['optimization', 'endtoend service', 'review campaigns', 'goal achievement', 'process implementation']
# ['innovation', '', '', '']
# ['great service', 'available team', 'efficient outreach', 'proactive review requests']
# ['less work', 'higher volume', 'higher quality', 'automated organization']
# ['hard', 'charms', 'support', 'support', 'recommend', 'initial setup', 'initial setup', 'time consuming', 'online business', 'rely on reviews', 'highly recommend', 'lifted work load', '', 'automated review process', 'automated review process', '', '']
# ['online', 'online', 'revenue', 'promoters', 'high rate', 'high rate', 'link results', 'link results', 'refer friends', 'writing reviews', 'writing reviews', 'back to revenue', '']
# ['build', 'outreach', 'reviews', 'promoters', 'platforms']
# ['live chat', 'integrations', 'email support', 'user experience', 'knowledge base', 'customer feedback', 'ticket management', 'realtime analytics', 'sentiment analysis', 'automated responses', 'customizable branding']
# ['get reviews', 'net promoters', 'explore users', 'automate process', 'continuously improve', '', 'refine market segments']
# ['feature', 'feature', 'feature', '', '']
# ['helpful setup', 'easy organization', 'quick integration', 'provided templates', 'engineered for success']
# ['software', 'feedback', 'advocates', 'marketing', 'development', 'personality', 'response times', 'customer success']
# ['and the ab', '', '', '', '']
# ['easy setup', 'rapid campaign results', 'flexible customer support', '']
# ['quick results', 'outstanding support', 'userfriendly interface', 'customer requirement understanding']
# ['getting setup', 'smooth process', 'first day usage', 'topnotch support', 'automatic followup']
# ['microsoft dynamics', '', '', '']
# ['sure', '']
# ['realtime data', 'userfriendly', 'collaborative', 'mobile access', 'usage reporting', 'realtime alerts', 'user level access', 'customizable views', 'customizable dashboards']
# ['']
# ['', 'grids', 'reporting', 'useful grids', '', 'user segmentation', 'advanced analysis', 'user segmentation', 'data visualization', 'intuitive interface', 'intuitive interface', 'reliable performance', 'sidebyside comparisons', 'sidebyside comparisons', 'efficient data visualization', '', '', '']
# ['easy setup', 'organization', 'good pricing']
# ['website', '', '']
# ['helpful team', 'intuitiveness', 'dedicated team', 'thorough support', '', '']
# ['prospects', 'credibility', 'easy campaigns', 'listing tools', 'building trust', 'close business', 'running reviews', 'marketing tools']
# ['and okay leads', 'decent customer service', '', '']
# ['feature user reviews', '', 'feature integrations', 'feature mobile access', 'feature lead management', 'feature market presence', 'feature customer support', 'feature sales forecasting', '', '', '', '', '']
# ['scalability', 'collaboration', 'realtime analytics', 'automate workflows', 'extensive features', 'userfriendly interface', 'great customer service', 'integration capabilities', '', '', '', '', '', '']
# ['', 'clean', 'slack', 'gmail', 'android', 'hubspot', 'no coding', 'customizable', 'gdpr compliant', 'google workspace', 'user interface intuitive', '', '', '', '', '']
# ['impartial reviews', 'preferred interface', 'great user experience', 'consumerbased review sites', 'trustworthy customer input', '']
# ['custom content', 'customer support', 'competitive analysis', '', 'organizationlike review process', '']
# ['seo', 'valued source', 'unbiased reviews', 'extensive user base', 'industry expertise', 'keywords sales leads', 'robust review process', 'productcompetitor awareness']
# ['vendor discovery', 'simple interface', 'easy to navigate', 'accurate information', '']
# ['helpful', 'responsive', 'instant chat', 'knowledgeable', '']
# ['helpful', 'friendly', 'honest reviews', 'customer support', 'opening feedback', 'showcasing value', 'holds accountable']
# ['mobile app', 'custom branding', 'document sharing', 'professional services', '', '', '']
# ['helpful team', 'questions assistance', '']
# ['grid reports', 'product focus', 'campaign management', 'marketplace relevancy', 'quick feedback collection']
# ['pricing', 'user experience', '', '', '']
# ['dashboard', 'widget tool', 'userfriendly', 'responsive team']
# ['usability', 'scalability', 'data security', 'intuitive interface', 'quick response time', 'customizable templates', 'efficient team management', '', 'personalized customer support', 'effective communication tools']
# ['']
# ['content', 'customers', 'opportunity', 'lead generation', 'sales resource', 'genuine feedback', 'harness feedback', 'marketing resource']
# ['', 'charts', 'website', 'export data', 'demographics', 'transactions', 'landing pages', 'registrations', 'search console', 'google analytics', 'audience overlap', 'location insights', 'competitors analysis', '', '', '', '', '']
# ['rankings reports', 'service reports', 'support reports', 'usability reports']
# ['award badges', 'backend options', 'reporting features']
# ['', '', '']
# ['easy navigation', 'seamless setup', 'multiple pages']
# ['if its', '', '']
# ['intuitive interface', 'vendor promotion tools', '', 'streamlined user experience', '']
# ['investors', '']
# ['']
# ['timesaving', 'informative', 'customizable', 'costeffective', 'large database', 'trusted source', 'communitydriven', 'genuine feedback', 'userfriendly design', '', 'comprehensive coverage', '']
# ['']
# ['secure', 'easy setup', 'affordable', 'scalability', 'dispatching', 'customizable', 'integrations', 'user friendly', 'mobile access', 'task management', 'crm integrations', 'contact management', 'real time tracking', 'workflow automation', 'customizable fields', 'multilanguage support', 'comprehensive support', 'reporting and analytics', 'customer relationship management', '']
# ['feature leads', 'feature analytics', '', '']
# ['prompt response', 'impeccable service', 'smooth onboarding process']
# ['', '', '', '', '', '']
# ['golden insights', 'supportive team', 'successoriented', 'lengthy feedback', 'easy implementation', '', 'optimized review formatting', '']
# ['engaging', 'new customers', 'user experience', 'differentiation', 'software references', 'potential customers']
# ['clear labeling', 'personable team', 'easytouse platform']
# ['profile assistance', 'easy contact support', 'suggestions for usage']
# ['reliable', 'easy setup', 'efficient', 'scalability', 'robust tools', 'customizable', 'costeffective', 'data protection', 'user management', 'frequent updates', 'intuitive design', 'flexible deployment', 'seamless integration', 'customizable branding', 'userfriendly interface', 'versatile applications', 'comprehensive reporting', 'thirdparty integrations', 'extensive knowledge base', '']
# ['scalable', 'security', 'easy setup', 'simple ui', 'mobile app', 'ab testing', 'easy to use', 'simple pricing', 'customer support', 'integration options', 'reports and analytics', 'automated email campaigns', '']
# ['quick', 'easytouse', 'userfriendly', 'researching', 'greatresource', 'emailmarketing', 'prospectivecustomers', 'emergencynotificationsoftware']
# ['easytouse', 'credibility', 'quick access', 'gaining trust', 'user interaction', 'brand awareness']
# ['inclusivity', 'straightforward', 'clear navigation', 'detailed reviews', 'userfriendly design', 'high quality images', 'comprehensive layout', 'quick loading interface']
# ['calendars', '', '']
# ['prompt responses', 'thorough answers', 'excellent customer service']
# ['responsive_csms', 'traffic_awareness']
# ['transparency', 'easy access', 'user reviews', 'trustbuilding', 'accountability', 'public channels', 'instant feedback', 'realtime updates', 'customer feedback', 'productive dialogue', 'learning from peers', 'community engagement', 'public accountability', 'userfriendly interface', 'constructive criticism', 'multiple rating systems', 'efficient communication', 'improvement opportunities']
# ['easy lives', 'transparency', 'verified users', 'hides nothing', 'genuine profiles', 'promotes good partnerships']
# ['']
# ['vendors', 'analytics', 'comparing', 'companies']
# ['', '']
# ['easy integration', 'robust security', 'extensive reporting', 'userfriendly interface', 'strong customer support']
# ['data', 'host assets', 'branded profile', 'client manager', '', 'competitive comparison reports']
# ['branding', 'customer reviews', 'online promotion', 'account management', 'contact information']
# ['benefit', 'benefit', 'edit widgets', 'easy to navigate', 'or benefits benefit', 'clean user interface', '', '', 'successful marketing campaign', '', '']
# ['', '', '']
# ['']
# ['profile updates', 'userfriendly interface', 'easy invitation process', 'customer advocacy promotion']
# ['insights', 'supportive', 'improve online reputation', '']
# ['']
# ['easy setup', 'seo tools', 'ab testing', 'form builder', 'landing pages', 'custom domain', 'email campaigns', 'lead generation', 'realtime analytics', 'social media integration']
# ['']
# ['referral program', 'customer reviews', 'sales enablement']
# ['simple set up', 'live integration', 'friendly approach', 'effective campaigning', 'integration specialist']
# ['']
# ['security', 'easy setup', 'cloudbased', 'scalability', 'integration', 'esignatures', 'mobile access', 'customer support', 'customizable forms', 'affordable pricing', 'document management', 'workflow automation', 'userfriendly interface', 'reporting and analytics']
# ['comparison grid', '', '']
# ['easy', 'filter reviews', 'data validation', 'respond globally', 'ai spam detection', 'account management', 'track review sources', 'social share reviews', 'professional services', 'educational resources', 'proactive suggestions', 'negative review handling', 'daily performance reports', 'automate response templates', '', '', '', '']
# ['']
# ['best onboarding experience', 'dedicated account manager', 'implementation specialist', '', '']
# ['']
# ['']

# %%
for review_id in copy_feature_dict:
    features = copy_feature_dict[review_id]
    if features == [""]:
        copy_feature_dict[review_id] = []
        continue
    
    # Create a new list to store the non-empty features
    cleaned_features = []
    
    for feature in features:
        if feature != "":
            cleaned_features.append(feature)
    
    # Update the features in the dictionary
    copy_feature_dict[review_id] = cleaned_features

# %%
corpus =[]
for review_id in copy_feature_dict:
    corpus.append(copy_feature_dict[review_id])

# %% [markdown]
# ### preprocessing

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import  PorterStemmer, WordNetLemmatizer
import string

# Function for text preprocessing
def preprocess_text(phrase):
    # Tokenization
    res = []
    for i in phrase:
        
        tokens = word_tokenize(i)
        stemmer = PorterStemmer()
        lemmatizer = WordNetLemmatizer()
        # Convert to lowercase
        tokens = [word.lower() for word in tokens]
        
        # Remove punctuation
        table = str.maketrans('', '', string.punctuation)
        tokens = [word.translate(table) for word in tokens]
        
        # Remove stopwords
        stop_words = set(stopwords.words('english'))
        
        # Stem tokens
        #tokens = [stemmer.stem(token) for token in tokens]
        tokens = [lemmatizer.lemmatize(token) for token in tokens]
        
        tokens = [word for word in tokens if word not in stop_words ]
        tokens = [word for word in tokens if not word.isdigit()]

        
        tokens= " ".join(tokens)
                
        res.append(tokens)
    return res

# %% [markdown]
# ### TFIDF VECTORIZATION + SIMILAR WORDS CLUSTER CREATION

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity


preprocessed_dataset = []
# Preprocess each document in the corpus
for i in range(len(corpus)):
    preprocessed_dataset.append(preprocess_text(corpus[i]))

# Flatten the preprocessed dataset
flattened_dataset = [item for sublist in preprocessed_dataset for item in sublist]

# TF-IDF Vectorization
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(flattened_dataset)

# Calculate pairwise cosine similarity
cosine_sim = cosine_similarity(tfidf_matrix)

# K-means clustering
k = 45# Number of clusters (adjust as needed)
kmeans = KMeans(n_clusters=k)
kmeans.fit(cosine_sim)

# Extracting important features from each cluster
clusters = {}
for i, label in enumerate(kmeans.labels_):
    if label not in clusters:
        clusters[label] = [flattened_dataset[i]]
    else:
        clusters[label].append(flattened_dataset[i])

# Print out important features in each cluster
for cluster_id, features in clusters.items():
    print(f"Cluster {cluster_id}:")
    for feature in features:
        print(f"- {feature}")
    print()
# Out:
# Cluster 1:
# - position
# - open forum
# - reference call
# - public validation
# - validation point
# - building pipeline
# - brand building
# - great start help
# - valuable platform understanding
# - optimization
# - goal achievement
# - innovation
# - le work
# - higher volume
# - higher quality
# - hard
# - charm
# - recommend
# - highly recommend
# - lifted work load
# - revenue
# - promoter
# - high rate
# - high rate
# - refer friend
# - back revenue
# - build
# - outreach
# - promoter
# - platform
# - live chat
# - sentiment analysis
# - net promoter
# - continuously improve
# - refine market segment
# - provided template
# - engineered success
# - software
# - advocate
# - development
# - personality
# - first day usage
# - automatic followup
# - microsoft dynamic
# - sure
# - collaborative
# - realtime alert
# - advanced analysis
# - reliable performance
# - good pricing
# - website
# - intuitiveness
# - prospect
# - credibility
# - building trust
# - close business
# - collaboration
# - clean
# - slack
# - gmail
# - android
# - hubspot
# - coding
# - gdpr compliant
# - google workspace
# - custom content
# - competitive analysis
# - seo
# - valued source
# - industry expertise
# - productcompetitor awareness
# - vendor discovery
# - accurate information
# - responsive
# - instant chat
# - knowledgeable
# - friendly
# - showcasing value
# - hold accountable
# - custom branding
# - document sharing
# - question assistance
# - product focus
# - marketplace relevancy
# - pricing
# - dashboard
# - usability
# - content
# - opportunity
# - chart
# - website
# - demographic
# - transaction
# - landing page
# - registration
# - search console
# - audience overlap
# - location insight
# - competitor analysis
# - ranking report
# - usability report
# - award badge
# - backend option
# - multiple page
# -
# - investor
# - timesaving
# - informative
# - costeffective
# - large database
# - trusted source
# - communitydriven
# - comprehensive coverage
# - secure
# - affordable
# - dispatching
# - real time tracking
# - golden insight
# - successoriented
# - engaging
# - differentiation
# - software reference
# - clear labeling
# - suggestion usage
# - reliable
# - costeffective
# - frequent update
# - flexible deployment
# - versatile application
# - scalable
# - simple ui
# - simple pricing
# - researching
# - greatresource
# - emailmarketing
# - prospectivecustomers
# - emergencynotificationsoftware
# - credibility
# - gaining trust
# - brand awareness
# - inclusivity
# - straightforward
# - clear navigation
# - high quality image
# - comprehensive layout
# - calendar
# - thorough answer
# - responsivecsms
# - trafficawareness
# - transparency
# - trustbuilding
# - accountability
# - public channel
# - realtime update
# - productive dialogue
# - learning peer
# - community engagement
# - public accountability
# - constructive criticism
# - multiple rating system
# - improvement opportunity
# - transparency
# - hide nothing
# - promotes good partnership
# - vendor
# - comparing
# - company
# - host asset
# - client manager
# - branding
# - contact information
# - benefit
# - benefit
# - edit widget
# - benefit benefit
# - insight
# - supportive
# - form builder
# - landing page
# - custom domain
# - referral program
# - simple set
# - friendly approach
# - effective campaigning
# - cloudbased
# - esignatures
# - affordable pricing
# - respond globally
# - ai spam detection
# - educational resource
# - proactive suggestion
# - daily performance report
# - best onboarding experience
# - dedicated account manager
#
# Cluster 33:
# - market profile
# - profile assistance
# - genuine profile
# - branded profile
# - profile update
#
# Cluster 8:
# - mobile access
# - mobile access
# - feature mobile access
# - mobile app
# - mobile access
# - mobile app
# - quick access
# - mobile access
#
# Cluster 28:
# - lead management
# - task management
# - team management
# - sale management
# - contact management
# - project management
# - ticket management
# - campaign management
# - efficient team management
# - task management
# - contact management
# - user management
# - account management
# - document management
# - account management
#
# Cluster 39:
# - sale forecasting
# - feature sale forecasting
# - sale resource
# - sale enablement
#
# Cluster 15:
# - email communication
# - efficient outreach
# - efficient data visualization
# - efficient
# - efficient communication
#
# Cluster 9:
# - marketing automation integration
#
# Cluster 21:
# - user success story
# - explore user
# - user level access
# - user segmentation
# - user segmentation
# - user friendly
# - user interaction
# - verified user
# - clean user interface
#
# Cluster 19:
# - endtoend service
# - great service
# - professional service
# - service report
# - impeccable service
# - professional service
#
# Cluster 0:
# - review campaign
# - proactive review request
# - rely review
# - automated review process
# - automated review process
# - writing review
# - writing review
# - review
# - get review
# - running review
# - impartial review
# - consumerbased review site
# - organizationlike review process
# - unbiased review
# - robust review process
# - honest review
# - optimized review formatting
# - detailed review
# - user review
# - filter review
# - track review source
# - social share review
# - negative review handling
#
# Cluster 34:
# - process implementation
# - automate process
# - smooth process
# - smooth onboarding process
# - implementation specialist
#
# Cluster 23:
# - available team
# - dedicated team
# - responsive team
# - supportive team
# - personable team
#
# Cluster 31:
# - automated organization
# - automated response
# - organization
#
# Cluster 10:
# - support
# - support
# - email support
# - outstanding support
# - topnotch support
# - thorough support
# - support report
# - multilanguage support
# - comprehensive support
# - easy contact support
#
# Cluster 24:
# - initial setup
# - initial setup
# - getting setup
# - seamless setup
#
# Cluster 44:
# - time consuming
# - response time
# - quick response time
# - prompt response
# - quick
# - quick loading interface
# - prompt response
# - automate response template
#
# Cluster 27:
# - online business
# - online
# - online
# - online promotion
# - improve online reputation
#
# Cluster 37:
# - link result
# - link result
# - rapid campaign result
# - quick result
# - automated email campaign
# - successful marketing campaign
# - email campaign
#
# Cluster 42:
# - integration
# - quick integration
# - integration capability
# - integration
# - crm integration
# - seamless integration
# - thirdparty integration
# - integration option
# - social medium integration
# - live integration
# - integration specialist
# - integration
#
# Cluster 12:
# - user experience
# - great user experience
# - user experience
# - streamlined user experience
# - user experience
#
# Cluster 38:
# - knowledge base
# - extensive user base
# - extensive knowledge base
#
# Cluster 35:
# - customer feedback
# - customer success
# - customer requirement understanding
# - trustworthy customer input
# - customer
# - new customer
# - potential customer
# - customer feedback
# - customer review
# - customer advocacy promotion
# - customer review
#
# Cluster 20:
# - realtime analytics
# - usage reporting
# - reporting
# - realtime analytics
# - google analytics
# - reporting analytics
# - comprehensive reporting
# - report analytics
# - analytics
# - extensive reporting
# - realtime analytics
# - reporting analytics
#
# Cluster 5:
# - customizable branding
# - customizable view
# - customizable dashboard
# - customizable
# - customizable template
# - customizable
# - customizable
# - customizable field
# - customizable
# - customizable branding
# - customizable form
#
# Cluster 4:
# - feature
# - feature
# - feature
# - feature user review
# - feature integration
# - feature lead management
# - feature market presence
# - extensive feature
# - reporting feature
# - feature lead
# - feature analytics
#
# Cluster 26:
# - helpful setup
# - helpful team
# - helpful
# - helpful
# - helpful team
#
# Cluster 14:
# - easy organization
#
# Cluster 11:
# - feedback
# - opening feedback
# - quick feedback collection
# - genuine feedback
# - harness feedback
# - genuine feedback
# - lengthy feedback
# - instant feedback
#
# Cluster 25:
# - marketing
# - listing tool
# - marketing tool
# - widget tool
# - effective communication tool
# - marketing resource
# - vendor promotion tool
# - robust tool
# - seo tool
#
# Cluster 32:
# - ab
# - ab testing
# - ab testing
#
# Cluster 3:
# - easy setup
# - easy setup
# - easy setup
# - easy setup
# - easy setup
# - easy setup
# - easy setup
#
# Cluster 17:
# - flexible customer support
# - customer support
# - customer support
# - personalized customer support
# - customer support
# - strong customer support
# - customer support
#
# Cluster 30:
# - userfriendly interface
# - userfriendly interface
# - userfriendly interface
# - userfriendly interface
# - userfriendly interface
# - userfriendly interface
# - userfriendly interface
#
# Cluster 16:
# - realtime data
# - data visualization
# - data security
# - export data
# - data protection
# - security
# - robust security
# - data
# - security
# - data validation
#
# Cluster 2:
# - userfriendly
# - userfriendly
# - userfriendly design
# - userfriendly
# - userfriendly design
#
# Cluster 29:
# - grid
# - useful grid
# - sidebyside comparison
# - sidebyside comparison
# - grid report
# - competitive comparison report
# - comparison grid
#
# Cluster 18:
# - intuitive interface
# - intuitive interface
# - user interface intuitive
# - preferred interface
# - simple interface
# - intuitive interface
# - intuitive interface
# - intuitive design
#
# Cluster 43:
# - easy campaign
# - easy navigate
# - easy navigation
# - easy implementation
# - easy use
# - easy access
# - easy life
# - easy integration
# - easy navigate
# - easy invitation process
# - easy
#
# Cluster 22:
# - okay lead
# - keywords sale lead
# - lead generation
# - lead generation
#
# Cluster 40:
# - decent customer service
# - great customer service
# - excellent customer service
#
# Cluster 6:
# - feature customer support
#
# Cluster 13:
# - scalability
# - scalability
# - scalability
# - scalability
# - scalability
#
# Cluster 41:
# - automate workflow
# - workflow automation
# - workflow automation
#
# Cluster 7:
# - customer relationship management
#
# Cluster 36:
# - easytouse platform
# - easytouse
# - easytouse

# %%
from collections import Counter

# Function to nominate two features from a cluster
def nominate_features(cluster):
    # Flatten the list of features in the cluster
    all_features = [feature for features in cluster for feature in features.split()]
    
    # Count the frequency of each term
    term_frequency = Counter(all_features)
    
    # Get the most frequent and second most frequent terms
    most_frequent_terms = term_frequency.most_common(6)
    
    return most_frequent_terms

# Dictionary to store the nominated features for each cluster
nominated_features = {}

# Nominate features for each cluster
for cluster_id, cluster_features in clusters.items():
    most_frequent_terms = nominate_features(cluster_features)
    nominated_features[cluster_id] = most_frequent_terms

# Print nominated features for each cluster
for cluster_id, nominated in nominated_features.items():
    print(f"Cluster {cluster_id}:")
    print("Nominated Features:")
    for rank, (term, frequency) in enumerate(nominated, start=1):
        
        print(f"{rank}. {term} (Frequency: {frequency})")
    print()
# Out:
# Cluster 1:
# Nominated Features:
# 1. analysis (Frequency: 4)
# 2. pricing (Frequency: 4)
# 3. benefit (Frequency: 4)
# 4. public (Frequency: 3)
# 5. building (Frequency: 3)
# 6. promoter (Frequency: 3)
#
# Cluster 33:
# Nominated Features:
# 1. profile (Frequency: 5)
# 2. market (Frequency: 1)
# 3. assistance (Frequency: 1)
# 4. genuine (Frequency: 1)
# 5. branded (Frequency: 1)
# 6. update (Frequency: 1)
#
# Cluster 8:
# Nominated Features:
# 1. mobile (Frequency: 7)
# 2. access (Frequency: 6)
# 3. app (Frequency: 2)
# 4. feature (Frequency: 1)
# 5. quick (Frequency: 1)
#
# Cluster 28:
# Nominated Features:
# 1. management (Frequency: 15)
# 2. task (Frequency: 2)
# 3. team (Frequency: 2)
# 4. contact (Frequency: 2)
# 5. account (Frequency: 2)
# 6. lead (Frequency: 1)
#
# Cluster 39:
# Nominated Features:
# 1. sale (Frequency: 4)
# 2. forecasting (Frequency: 2)
# 3. feature (Frequency: 1)
# 4. resource (Frequency: 1)
# 5. enablement (Frequency: 1)
#
# Cluster 15:
# Nominated Features:
# 1. efficient (Frequency: 4)
# 2. communication (Frequency: 2)
# 3. email (Frequency: 1)
# 4. outreach (Frequency: 1)
# 5. data (Frequency: 1)
# 6. visualization (Frequency: 1)
#
# Cluster 9:
# Nominated Features:
# 1. marketing (Frequency: 1)
# 2. automation (Frequency: 1)
# 3. integration (Frequency: 1)
#
# Cluster 21:
# Nominated Features:
# 1. user (Frequency: 9)
# 2. segmentation (Frequency: 2)
# 3. success (Frequency: 1)
# 4. story (Frequency: 1)
# 5. explore (Frequency: 1)
# 6. level (Frequency: 1)
#
# Cluster 19:
# Nominated Features:
# 1. service (Frequency: 6)
# 2. professional (Frequency: 2)
# 3. endtoend (Frequency: 1)
# 4. great (Frequency: 1)
# 5. report (Frequency: 1)
# 6. impeccable (Frequency: 1)
#
# Cluster 0:
# Nominated Features:
# 1. review (Frequency: 23)
# 2. process (Frequency: 4)
# 3. automated (Frequency: 2)
# 4. writing (Frequency: 2)
# 5. campaign (Frequency: 1)
# 6. proactive (Frequency: 1)
#
# Cluster 34:
# Nominated Features:
# 1. process (Frequency: 4)
# 2. implementation (Frequency: 2)
# 3. smooth (Frequency: 2)
# 4. automate (Frequency: 1)
# 5. onboarding (Frequency: 1)
# 6. specialist (Frequency: 1)
#
# Cluster 23:
# Nominated Features:
# 1. team (Frequency: 5)
# 2. available (Frequency: 1)
# 3. dedicated (Frequency: 1)
# 4. responsive (Frequency: 1)
# 5. supportive (Frequency: 1)
# 6. personable (Frequency: 1)
#
# Cluster 31:
# Nominated Features:
# 1. automated (Frequency: 2)
# 2. organization (Frequency: 2)
# 3. response (Frequency: 1)
#
# Cluster 10:
# Nominated Features:
# 1. support (Frequency: 10)
# 2. email (Frequency: 1)
# 3. outstanding (Frequency: 1)
# 4. topnotch (Frequency: 1)
# 5. thorough (Frequency: 1)
# 6. report (Frequency: 1)
#
# Cluster 24:
# Nominated Features:
# 1. setup (Frequency: 4)
# 2. initial (Frequency: 2)
# 3. getting (Frequency: 1)
# 4. seamless (Frequency: 1)
#
# Cluster 44:
# Nominated Features:
# 1. response (Frequency: 5)
# 2. time (Frequency: 3)
# 3. quick (Frequency: 3)
# 4. prompt (Frequency: 2)
# 5. consuming (Frequency: 1)
# 6. loading (Frequency: 1)
#
# Cluster 27:
# Nominated Features:
# 1. online (Frequency: 5)
# 2. business (Frequency: 1)
# 3. promotion (Frequency: 1)
# 4. improve (Frequency: 1)
# 5. reputation (Frequency: 1)
#
# Cluster 37:
# Nominated Features:
# 1. result (Frequency: 4)
# 2. campaign (Frequency: 4)
# 3. link (Frequency: 2)
# 4. email (Frequency: 2)
# 5. rapid (Frequency: 1)
# 6. quick (Frequency: 1)
#
# Cluster 42:
# Nominated Features:
# 1. integration (Frequency: 12)
# 2. quick (Frequency: 1)
# 3. capability (Frequency: 1)
# 4. crm (Frequency: 1)
# 5. seamless (Frequency: 1)
# 6. thirdparty (Frequency: 1)
#
# Cluster 12:
# Nominated Features:
# 1. user (Frequency: 5)
# 2. experience (Frequency: 5)
# 3. great (Frequency: 1)
# 4. streamlined (Frequency: 1)
#
# Cluster 38:
# Nominated Features:
# 1. base (Frequency: 3)
# 2. knowledge (Frequency: 2)
# 3. extensive (Frequency: 2)
# 4. user (Frequency: 1)
#
# Cluster 35:
# Nominated Features:
# 1. customer (Frequency: 11)
# 2. feedback (Frequency: 2)
# 3. review (Frequency: 2)
# 4. success (Frequency: 1)
# 5. requirement (Frequency: 1)
# 6. understanding (Frequency: 1)
#
# Cluster 20:
# Nominated Features:
# 1. analytics (Frequency: 8)
# 2. reporting (Frequency: 6)
# 3. realtime (Frequency: 3)
# 4. usage (Frequency: 1)
# 5. google (Frequency: 1)
# 6. comprehensive (Frequency: 1)
#
# Cluster 5:
# Nominated Features:
# 1. customizable (Frequency: 11)
# 2. branding (Frequency: 2)
# 3. view (Frequency: 1)
# 4. dashboard (Frequency: 1)
# 5. template (Frequency: 1)
# 6. field (Frequency: 1)
#
# Cluster 4:
# Nominated Features:
# 1. feature (Frequency: 11)
# 2. lead (Frequency: 2)
# 3. user (Frequency: 1)
# 4. review (Frequency: 1)
# 5. integration (Frequency: 1)
# 6. management (Frequency: 1)
#
# Cluster 26:
# Nominated Features:
# 1. helpful (Frequency: 5)
# 2. team (Frequency: 2)
# 3. setup (Frequency: 1)
#
# Cluster 14:
# Nominated Features:
# 1. easy (Frequency: 1)
# 2. organization (Frequency: 1)
#
# Cluster 11:
# Nominated Features:
# 1. feedback (Frequency: 8)
# 2. genuine (Frequency: 2)
# 3. opening (Frequency: 1)
# 4. quick (Frequency: 1)
# 5. collection (Frequency: 1)
# 6. harness (Frequency: 1)
#
# Cluster 25:
# Nominated Features:
# 1. tool (Frequency: 7)
# 2. marketing (Frequency: 3)
# 3. listing (Frequency: 1)
# 4. widget (Frequency: 1)
# 5. effective (Frequency: 1)
# 6. communication (Frequency: 1)
#
# Cluster 32:
# Nominated Features:
# 1. ab (Frequency: 3)
# 2. testing (Frequency: 2)
#
# Cluster 3:
# Nominated Features:
# 1. easy (Frequency: 7)
# 2. setup (Frequency: 7)
#
# Cluster 17:
# Nominated Features:
# 1. customer (Frequency: 7)
# 2. support (Frequency: 7)
# 3. flexible (Frequency: 1)
# 4. personalized (Frequency: 1)
# 5. strong (Frequency: 1)
#
# Cluster 30:
# Nominated Features:
# 1. userfriendly (Frequency: 7)
# 2. interface (Frequency: 7)
#
# Cluster 16:
# Nominated Features:
# 1. data (Frequency: 7)
# 2. security (Frequency: 4)
# 3. realtime (Frequency: 1)
# 4. visualization (Frequency: 1)
# 5. export (Frequency: 1)
# 6. protection (Frequency: 1)
#
# Cluster 2:
# Nominated Features:
# 1. userfriendly (Frequency: 5)
# 2. design (Frequency: 2)
#
# Cluster 29:
# Nominated Features:
# 1. grid (Frequency: 4)
# 2. comparison (Frequency: 4)
# 3. sidebyside (Frequency: 2)
# 4. report (Frequency: 2)
# 5. useful (Frequency: 1)
# 6. competitive (Frequency: 1)
#
# Cluster 18:
# Nominated Features:
# 1. interface (Frequency: 7)
# 2. intuitive (Frequency: 6)
# 3. user (Frequency: 1)
# 4. preferred (Frequency: 1)
# 5. simple (Frequency: 1)
# 6. design (Frequency: 1)
#
# Cluster 43:
# Nominated Features:
# 1. easy (Frequency: 11)
# 2. navigate (Frequency: 2)
# 3. campaign (Frequency: 1)
# 4. navigation (Frequency: 1)
# 5. implementation (Frequency: 1)
# 6. use (Frequency: 1)
#
# Cluster 22:
# Nominated Features:
# 1. lead (Frequency: 4)
# 2. generation (Frequency: 2)
# 3. okay (Frequency: 1)
# 4. keywords (Frequency: 1)
# 5. sale (Frequency: 1)
#
# Cluster 40:
# Nominated Features:
# 1. customer (Frequency: 3)
# 2. service (Frequency: 3)
# 3. decent (Frequency: 1)
# 4. great (Frequency: 1)
# 5. excellent (Frequency: 1)
#
# Cluster 6:
# Nominated Features:
# 1. feature (Frequency: 1)
# 2. customer (Frequency: 1)
# 3. support (Frequency: 1)
#
# Cluster 13:
# Nominated Features:
# 1. scalability (Frequency: 5)
#
# Cluster 41:
# Nominated Features:
# 1. workflow (Frequency: 3)
# 2. automation (Frequency: 2)
# 3. automate (Frequency: 1)
#
# Cluster 7:
# Nominated Features:
# 1. customer (Frequency: 1)
# 2. relationship (Frequency: 1)
# 3. management (Frequency: 1)
#
# Cluster 36:
# Nominated Features:
# 1. easytouse (Frequency: 3)
# 2. platform (Frequency: 1)

# %%
def find_word_freq(cluster):
    all_features = [feature for features in cluster for feature in features.split()]
    term_frequency = Counter(all_features)
    return term_frequency


cluster_frequency = {}
for cluster_id, cluster_features in clusters.items():
    term_frequency = find_word_freq(cluster_features)
    cluster_frequency[cluster_id] = term_frequency

# %%
# Update clusters dictionary to include feature importance
for cluster_id, cluster in clusters.items():
    clusters[cluster_id] = []
    for feature in cluster:
        features = feature.split()
        feature_importance = sum(cluster_frequency[cluster_id].get(word, 0) for word in features)
        clusters[cluster_id].append({"feature": feature, "importance": feature_importance})

# %%
# Sort clusters based on the total importance
sorted_clusters = sorted(clusters.items(), key=lambda x: sum(feature["importance"] for feature in x[1]), reverse=True)

# Sort features within each cluster based on their importance
for cluster_id, cluster_features in sorted_clusters:
    sorted_features = sorted(cluster_features, key=lambda x: x["importance"], reverse=True)
    clusters[cluster_id] = sorted_features

# Print sorted clusters
for cluster_id, cluster_features in sorted_clusters:
    print(f"Cluster {cluster_id}:")
    for feature in cluster_features:
        print(f"- {feature['feature']} (Importance: {feature['importance']})")
    print()
# Out:
# Cluster 0:
# - review campaign (Importance: 24)
# - proactive review request (Importance: 25)
# - rely review (Importance: 24)
# - automated review process (Importance: 29)
# - automated review process (Importance: 29)
# - writing review (Importance: 25)
# - writing review (Importance: 25)
# - review (Importance: 23)
# - get review (Importance: 24)
# - running review (Importance: 24)
# - impartial review (Importance: 24)
# - consumerbased review site (Importance: 25)
# - organizationlike review process (Importance: 28)
# - unbiased review (Importance: 24)
# - robust review process (Importance: 28)
# - honest review (Importance: 24)
# - optimized review formatting (Importance: 25)
# - detailed review (Importance: 24)
# - user review (Importance: 24)
# - filter review (Importance: 24)
# - track review source (Importance: 25)
# - social share review (Importance: 25)
# - negative review handling (Importance: 25)
#
# Cluster 1:
# - position (Importance: 1)
# - open forum (Importance: 2)
# - reference call (Importance: 3)
# - public validation (Importance: 5)
# - validation point (Importance: 3)
# - building pipeline (Importance: 4)
# - brand building (Importance: 5)
# - great start help (Importance: 3)
# - valuable platform understanding (Importance: 4)
# - optimization (Importance: 1)
# - goal achievement (Importance: 2)
# - innovation (Importance: 1)
# - le work (Importance: 3)
# - higher volume (Importance: 3)
# - higher quality (Importance: 4)
# - hard (Importance: 1)
# - charm (Importance: 1)
# - recommend (Importance: 2)
# - highly recommend (Importance: 3)
# - lifted work load (Importance: 4)
# - revenue (Importance: 2)
# - promoter (Importance: 3)
# - high rate (Importance: 5)
# - high rate (Importance: 5)
# - refer friend (Importance: 2)
# - back revenue (Importance: 3)
# - build (Importance: 1)
# - outreach (Importance: 1)
# - promoter (Importance: 3)
# - platform (Importance: 2)
# - live chat (Importance: 3)
# - sentiment analysis (Importance: 5)
# - net promoter (Importance: 4)
# - continuously improve (Importance: 2)
# - refine market segment (Importance: 3)
# - provided template (Importance: 2)
# - engineered success (Importance: 2)
# - software (Importance: 2)
# - advocate (Importance: 1)
# - development (Importance: 1)
# - personality (Importance: 1)
# - first day usage (Importance: 4)
# - automatic followup (Importance: 2)
# - microsoft dynamic (Importance: 2)
# - sure (Importance: 1)
# - collaborative (Importance: 1)
# - realtime alert (Importance: 3)
# - advanced analysis (Importance: 5)
# - reliable performance (Importance: 4)
# - good pricing (Importance: 6)
# - website (Importance: 2)
# - intuitiveness (Importance: 1)
# - prospect (Importance: 1)
# - credibility (Importance: 2)
# - building trust (Importance: 5)
# - close business (Importance: 2)
# - collaboration (Importance: 1)
# - clean (Importance: 1)
# - slack (Importance: 1)
# - gmail (Importance: 1)
# - android (Importance: 1)
# - hubspot (Importance: 1)
# - coding (Importance: 1)
# - gdpr compliant (Importance: 2)
# - google workspace (Importance: 2)
# - custom content (Importance: 5)
# - competitive analysis (Importance: 5)
# - seo (Importance: 1)
# - valued source (Importance: 3)
# - industry expertise (Importance: 2)
# - productcompetitor awareness (Importance: 3)
# - vendor discovery (Importance: 3)
# - accurate information (Importance: 3)
# - responsive (Importance: 1)
# - instant chat (Importance: 3)
# - knowledgeable (Importance: 1)
# - friendly (Importance: 2)
# - showcasing value (Importance: 2)
# - hold accountable (Importance: 2)
# - custom branding (Importance: 5)
# - document sharing (Importance: 2)
# - question assistance (Importance: 2)
# - product focus (Importance: 2)
# - marketplace relevancy (Importance: 2)
# - pricing (Importance: 4)
# - dashboard (Importance: 1)
# - usability (Importance: 2)
# - content (Importance: 2)
# - opportunity (Importance: 2)
# - chart (Importance: 1)
# - website (Importance: 2)
# - demographic (Importance: 1)
# - transaction (Importance: 1)
# - landing page (Importance: 5)
# - registration (Importance: 1)
# - search console (Importance: 2)
# - audience overlap (Importance: 2)
# - location insight (Importance: 4)
# - competitor analysis (Importance: 5)
# - ranking report (Importance: 4)
# - usability report (Importance: 5)
# - award badge (Importance: 2)
# - backend option (Importance: 2)
# - multiple page (Importance: 5)
# -  (Importance: 0)
# - investor (Importance: 1)
# - timesaving (Importance: 1)
# - informative (Importance: 1)
# - costeffective (Importance: 2)
# - large database (Importance: 2)
# - trusted source (Importance: 3)
# - communitydriven (Importance: 1)
# - comprehensive coverage (Importance: 3)
# - secure (Importance: 1)
# - affordable (Importance: 2)
# - dispatching (Importance: 1)
# - real time tracking (Importance: 3)
# - golden insight (Importance: 4)
# - successoriented (Importance: 1)
# - engaging (Importance: 1)
# - differentiation (Importance: 1)
# - software reference (Importance: 4)
# - clear labeling (Importance: 3)
# - suggestion usage (Importance: 4)
# - reliable (Importance: 2)
# - costeffective (Importance: 2)
# - frequent update (Importance: 3)
# - flexible deployment (Importance: 2)
# - versatile application (Importance: 2)
# - scalable (Importance: 1)
# - simple ui (Importance: 4)
# - simple pricing (Importance: 7)
# - researching (Importance: 1)
# - greatresource (Importance: 1)
# - emailmarketing (Importance: 1)
# - prospectivecustomers (Importance: 1)
# - emergencynotificationsoftware (Importance: 1)
# - credibility (Importance: 2)
# - gaining trust (Importance: 3)
# - brand awareness (Importance: 4)
# - inclusivity (Importance: 1)
# - straightforward (Importance: 1)
# - clear navigation (Importance: 3)
# - high quality image (Importance: 6)
# - comprehensive layout (Importance: 3)
# - calendar (Importance: 1)
# - thorough answer (Importance: 2)
# - responsivecsms (Importance: 1)
# - trafficawareness (Importance: 1)
# - transparency (Importance: 2)
# - trustbuilding (Importance: 1)
# - accountability (Importance: 2)
# - public channel (Importance: 4)
# - realtime update (Importance: 4)
# - productive dialogue (Importance: 2)
# - learning peer (Importance: 2)
# - community engagement (Importance: 2)
# - public accountability (Importance: 5)
# - constructive criticism (Importance: 2)
# - multiple rating system (Importance: 4)
# - improvement opportunity (Importance: 3)
# - transparency (Importance: 2)
# - hide nothing (Importance: 2)
# - promotes good partnership (Importance: 4)
# - vendor (Importance: 2)
# - comparing (Importance: 1)
# - company (Importance: 1)
# - host asset (Importance: 2)
# - client manager (Importance: 3)
# - branding (Importance: 2)
# - contact information (Importance: 3)
# - benefit (Importance: 4)
# - benefit (Importance: 4)
# - edit widget (Importance: 2)
# - benefit benefit (Importance: 8)
# - insight (Importance: 3)
# - supportive (Importance: 1)
# - form builder (Importance: 2)
# - landing page (Importance: 5)
# - custom domain (Importance: 4)
# - referral program (Importance: 2)
# - simple set (Importance: 4)
# - friendly approach (Importance: 3)
# - effective campaigning (Importance: 2)
# - cloudbased (Importance: 1)
# - esignatures (Importance: 1)
# - affordable pricing (Importance: 6)
# - respond globally (Importance: 2)
# - ai spam detection (Importance: 3)
# - educational resource (Importance: 2)
# - proactive suggestion (Importance: 3)
# - daily performance report (Importance: 6)
# - best onboarding experience (Importance: 3)
# - dedicated account manager (Importance: 4)
#
# Cluster 28:
# - lead management (Importance: 16)
# - task management (Importance: 17)
# - team management (Importance: 17)
# - sale management (Importance: 16)
# - contact management (Importance: 17)
# - project management (Importance: 16)
# - ticket management (Importance: 16)
# - campaign management (Importance: 16)
# - efficient team management (Importance: 18)
# - task management (Importance: 17)
# - contact management (Importance: 17)
# - user management (Importance: 16)
# - account management (Importance: 17)
# - document management (Importance: 16)
# - account management (Importance: 17)
#
# Cluster 42:
# - integration (Importance: 12)
# - quick integration (Importance: 13)
# - integration capability (Importance: 13)
# - integration (Importance: 12)
# - crm integration (Importance: 13)
# - seamless integration (Importance: 13)
# - thirdparty integration (Importance: 13)
# - integration option (Importance: 13)
# - social medium integration (Importance: 14)
# - live integration (Importance: 13)
# - integration specialist (Importance: 13)
# - integration (Importance: 12)
#
# Cluster 35:
# - customer feedback (Importance: 13)
# - customer success (Importance: 12)
# - customer requirement understanding (Importance: 13)
# - trustworthy customer input (Importance: 13)
# - customer (Importance: 11)
# - new customer (Importance: 12)
# - potential customer (Importance: 12)
# - customer feedback (Importance: 13)
# - customer review (Importance: 13)
# - customer advocacy promotion (Importance: 13)
# - customer review (Importance: 13)
#
# Cluster 4:
# - feature (Importance: 11)
# - feature (Importance: 11)
# - feature (Importance: 11)
# - feature user review (Importance: 13)
# - feature integration (Importance: 12)
# - feature lead management (Importance: 14)
# - feature market presence (Importance: 13)
# - extensive feature (Importance: 12)
# - reporting feature (Importance: 12)
# - feature lead (Importance: 13)
# - feature analytics (Importance: 12)
#
# Cluster 43:
# - easy campaign (Importance: 12)
# - easy navigate (Importance: 13)
# - easy navigation (Importance: 12)
# - easy implementation (Importance: 12)
# - easy use (Importance: 12)
# - easy access (Importance: 12)
# - easy life (Importance: 12)
# - easy integration (Importance: 12)
# - easy navigate (Importance: 13)
# - easy invitation process (Importance: 13)
# - easy (Importance: 11)
#
# Cluster 5:
# - customizable branding (Importance: 13)
# - customizable view (Importance: 12)
# - customizable dashboard (Importance: 12)
# - customizable (Importance: 11)
# - customizable template (Importance: 12)
# - customizable (Importance: 11)
# - customizable (Importance: 11)
# - customizable field (Importance: 12)
# - customizable (Importance: 11)
# - customizable branding (Importance: 13)
# - customizable form (Importance: 12)
#
# Cluster 20:
# - realtime analytics (Importance: 11)
# - usage reporting (Importance: 7)
# - reporting (Importance: 6)
# - realtime analytics (Importance: 11)
# - google analytics (Importance: 9)
# - reporting analytics (Importance: 14)
# - comprehensive reporting (Importance: 7)
# - report analytics (Importance: 9)
# - analytics (Importance: 8)
# - extensive reporting (Importance: 7)
# - realtime analytics (Importance: 11)
# - reporting analytics (Importance: 14)
#
# Cluster 10:
# - support (Importance: 10)
# - support (Importance: 10)
# - email support (Importance: 11)
# - outstanding support (Importance: 11)
# - topnotch support (Importance: 11)
# - thorough support (Importance: 11)
# - support report (Importance: 11)
# - multilanguage support (Importance: 11)
# - comprehensive support (Importance: 11)
# - easy contact support (Importance: 12)
#
# Cluster 17:
# - flexible customer support (Importance: 15)
# - customer support (Importance: 14)
# - customer support (Importance: 14)
# - personalized customer support (Importance: 15)
# - customer support (Importance: 14)
# - strong customer support (Importance: 15)
# - customer support (Importance: 14)
#
# Cluster 3:
# - easy setup (Importance: 14)
# - easy setup (Importance: 14)
# - easy setup (Importance: 14)
# - easy setup (Importance: 14)
# - easy setup (Importance: 14)
# - easy setup (Importance: 14)
# - easy setup (Importance: 14)
#
# Cluster 30:
# - userfriendly interface (Importance: 14)
# - userfriendly interface (Importance: 14)
# - userfriendly interface (Importance: 14)
# - userfriendly interface (Importance: 14)
# - userfriendly interface (Importance: 14)
# - userfriendly interface (Importance: 14)
# - userfriendly interface (Importance: 14)
#
# Cluster 21:
# - user success story (Importance: 11)
# - explore user (Importance: 10)
# - user level access (Importance: 11)
# - user segmentation (Importance: 11)
# - user segmentation (Importance: 11)
# - user friendly (Importance: 10)
# - user interaction (Importance: 10)
# - verified user (Importance: 10)
# - clean user interface (Importance: 11)
#
# Cluster 8:
# - mobile access (Importance: 13)
# - mobile access (Importance: 13)
# - feature mobile access (Importance: 14)
# - mobile app (Importance: 9)
# - mobile access (Importance: 13)
# - mobile app (Importance: 9)
# - quick access (Importance: 7)
# - mobile access (Importance: 13)
#
# Cluster 18:
# - intuitive interface (Importance: 13)
# - intuitive interface (Importance: 13)
# - user interface intuitive (Importance: 14)
# - preferred interface (Importance: 8)
# - simple interface (Importance: 8)
# - intuitive interface (Importance: 13)
# - intuitive interface (Importance: 13)
# - intuitive design (Importance: 7)
#
# Cluster 11:
# - feedback (Importance: 8)
# - opening feedback (Importance: 9)
# - quick feedback collection (Importance: 10)
# - genuine feedback (Importance: 10)
# - harness feedback (Importance: 9)
# - genuine feedback (Importance: 10)
# - lengthy feedback (Importance: 9)
# - instant feedback (Importance: 9)
#
# Cluster 16:
# - realtime data (Importance: 8)
# - data visualization (Importance: 8)
# - data security (Importance: 11)
# - export data (Importance: 8)
# - data protection (Importance: 8)
# - security (Importance: 4)
# - robust security (Importance: 5)
# - data (Importance: 7)
# - security (Importance: 4)
# - data validation (Importance: 8)
#
# Cluster 25:
# - marketing (Importance: 3)
# - listing tool (Importance: 8)
# - marketing tool (Importance: 10)
# - widget tool (Importance: 8)
# - effective communication tool (Importance: 9)
# - marketing resource (Importance: 4)
# - vendor promotion tool (Importance: 9)
# - robust tool (Importance: 8)
# - seo tool (Importance: 8)
#
# Cluster 44:
# - time consuming (Importance: 4)
# - response time (Importance: 8)
# - quick response time (Importance: 11)
# - prompt response (Importance: 7)
# - quick (Importance: 3)
# - quick loading interface (Importance: 5)
# - prompt response (Importance: 7)
# - automate response template (Importance: 7)
#
# Cluster 12:
# - user experience (Importance: 10)
# - great user experience (Importance: 11)
# - user experience (Importance: 10)
# - streamlined user experience (Importance: 11)
# - user experience (Importance: 10)
#
# Cluster 37:
# - link result (Importance: 6)
# - link result (Importance: 6)
# - rapid campaign result (Importance: 9)
# - quick result (Importance: 5)
# - automated email campaign (Importance: 7)
# - successful marketing campaign (Importance: 6)
# - email campaign (Importance: 6)
#
# Cluster 19:
# - endtoend service (Importance: 7)
# - great service (Importance: 7)
# - professional service (Importance: 8)
# - service report (Importance: 7)
# - impeccable service (Importance: 7)
# - professional service (Importance: 8)
#
# Cluster 29:
# - grid (Importance: 4)
# - useful grid (Importance: 5)
# - sidebyside comparison (Importance: 6)
# - sidebyside comparison (Importance: 6)
# - grid report (Importance: 6)
# - competitive comparison report (Importance: 7)
# - comparison grid (Importance: 8)
#
# Cluster 33:
# - market profile (Importance: 6)
# - profile assistance (Importance: 6)
# - genuine profile (Importance: 6)
# - branded profile (Importance: 6)
# - profile update (Importance: 6)
#
# Cluster 23:
# - available team (Importance: 6)
# - dedicated team (Importance: 6)
# - responsive team (Importance: 6)
# - supportive team (Importance: 6)
# - personable team (Importance: 6)
#
# Cluster 26:
# - helpful setup (Importance: 6)
# - helpful team (Importance: 7)
# - helpful (Importance: 5)
# - helpful (Importance: 5)
# - helpful team (Importance: 7)
#
# Cluster 27:
# - online business (Importance: 6)
# - online (Importance: 5)
# - online (Importance: 5)
# - online promotion (Importance: 6)
# - improve online reputation (Importance: 7)
#
# Cluster 2:
# - userfriendly (Importance: 5)
# - userfriendly (Importance: 5)
# - userfriendly design (Importance: 7)
# - userfriendly (Importance: 5)
# - userfriendly design (Importance: 7)
#
# Cluster 34:
# - process implementation (Importance: 6)
# - automate process (Importance: 5)
# - smooth process (Importance: 6)
# - smooth onboarding process (Importance: 7)
# - implementation specialist (Importance: 3)
#
# Cluster 13:
# - scalability (Importance: 5)
# - scalability (Importance: 5)
# - scalability (Importance: 5)
# - scalability (Importance: 5)
# - scalability (Importance: 5)
#
# Cluster 15:
# - email communication (Importance: 3)
# - efficient outreach (Importance: 5)
# - efficient data visualization (Importance: 6)
# - efficient (Importance: 4)
# - efficient communication (Importance: 6)
#
# Cluster 39:
# - sale forecasting (Importance: 6)
# - feature sale forecasting (Importance: 7)
# - sale resource (Importance: 5)
# - sale enablement (Importance: 5)
#
# Cluster 22:
# - okay lead (Importance: 5)
# - keywords sale lead (Importance: 6)
# - lead generation (Importance: 6)
# - lead generation (Importance: 6)
#
# Cluster 24:
# - initial setup (Importance: 6)
# - initial setup (Importance: 6)
# - getting setup (Importance: 5)
# - seamless setup (Importance: 5)
#
# Cluster 40:
# - decent customer service (Importance: 7)
# - great customer service (Importance: 7)
# - excellent customer service (Importance: 7)
#
# Cluster 38:
# - knowledge base (Importance: 5)
# - extensive user base (Importance: 6)
# - extensive knowledge base (Importance: 7)
#
# Cluster 41:
# - automate workflow (Importance: 4)
# - workflow automation (Importance: 5)
# - workflow automation (Importance: 5)
#
# Cluster 32:
# - ab (Importance: 3)
# - ab testing (Importance: 5)
# - ab testing (Importance: 5)
#
# Cluster 36:
# - easytouse platform (Importance: 4)
# - easytouse (Importance: 3)
# - easytouse (Importance: 3)
#
# Cluster 31:
# - automated organization (Importance: 4)
# - automated response (Importance: 3)
# - organization (Importance: 2)
#
# Cluster 9:
# - marketing automation integration (Importance: 3)
#
# Cluster 6:
# - feature customer support (Importance: 3)
#
# Cluster 7:
# - customer relationship management (Importance: 3)
#
# Cluster 14:
# - easy organization (Importance: 2)

# %%
# Remove duplicates within each cluster
for cluster_id, cluster_features in clusters.items():
    unique_features = []
    seen_features = set()
    for feature in cluster_features:
        if feature["feature"] not in seen_features:
            unique_features.append(feature)
            seen_features.add(feature["feature"])
    clusters[cluster_id] = unique_features

# Sort clusters based on the total importance
sorted_clusters = sorted(clusters.items(), key=lambda x: sum(feature["importance"] for feature in x[1]), reverse=True)

# Sort features within each cluster based on their importance
for cluster_id, cluster_features in sorted_clusters:
    sorted_features = sorted(cluster_features, key=lambda x: x["importance"], reverse=True)
    clusters[cluster_id] = sorted_features

# Print sorted clusters with duplicates removed
for cluster_id, cluster_features in sorted_clusters:
    print(f"Cluster {cluster_id}:")
    for feature in cluster_features:
        print(f"- {feature['feature']} (Importance: {feature['importance']})")
    print()
# Out:
# Cluster 0:
# - automated review process (Importance: 29)
# - organizationlike review process (Importance: 28)
# - robust review process (Importance: 28)
# - proactive review request (Importance: 25)
# - writing review (Importance: 25)
# - consumerbased review site (Importance: 25)
# - optimized review formatting (Importance: 25)
# - track review source (Importance: 25)
# - social share review (Importance: 25)
# - negative review handling (Importance: 25)
# - review campaign (Importance: 24)
# - rely review (Importance: 24)
# - get review (Importance: 24)
# - running review (Importance: 24)
# - impartial review (Importance: 24)
# - unbiased review (Importance: 24)
# - honest review (Importance: 24)
# - detailed review (Importance: 24)
# - user review (Importance: 24)
# - filter review (Importance: 24)
# - review (Importance: 23)
#
# Cluster 1:
# - benefit benefit (Importance: 8)
# - simple pricing (Importance: 7)
# - good pricing (Importance: 6)
# - high quality image (Importance: 6)
# - affordable pricing (Importance: 6)
# - daily performance report (Importance: 6)
# - public validation (Importance: 5)
# - brand building (Importance: 5)
# - high rate (Importance: 5)
# - sentiment analysis (Importance: 5)
# - advanced analysis (Importance: 5)
# - building trust (Importance: 5)
# - custom content (Importance: 5)
# - competitive analysis (Importance: 5)
# - custom branding (Importance: 5)
# - landing page (Importance: 5)
# - competitor analysis (Importance: 5)
# - usability report (Importance: 5)
# - multiple page (Importance: 5)
# - public accountability (Importance: 5)
# - building pipeline (Importance: 4)
# - valuable platform understanding (Importance: 4)
# - higher quality (Importance: 4)
# - lifted work load (Importance: 4)
# - net promoter (Importance: 4)
# - first day usage (Importance: 4)
# - reliable performance (Importance: 4)
# - pricing (Importance: 4)
# - location insight (Importance: 4)
# - ranking report (Importance: 4)
# - golden insight (Importance: 4)
# - software reference (Importance: 4)
# - suggestion usage (Importance: 4)
# - simple ui (Importance: 4)
# - brand awareness (Importance: 4)
# - public channel (Importance: 4)
# - realtime update (Importance: 4)
# - multiple rating system (Importance: 4)
# - promotes good partnership (Importance: 4)
# - benefit (Importance: 4)
# - custom domain (Importance: 4)
# - simple set (Importance: 4)
# - dedicated account manager (Importance: 4)
# - reference call (Importance: 3)
# - validation point (Importance: 3)
# - great start help (Importance: 3)
# - le work (Importance: 3)
# - higher volume (Importance: 3)
# - highly recommend (Importance: 3)
# - promoter (Importance: 3)
# - back revenue (Importance: 3)
# - live chat (Importance: 3)
# - refine market segment (Importance: 3)
# - realtime alert (Importance: 3)
# - valued source (Importance: 3)
# - productcompetitor awareness (Importance: 3)
# - vendor discovery (Importance: 3)
# - accurate information (Importance: 3)
# - instant chat (Importance: 3)
# - trusted source (Importance: 3)
# - comprehensive coverage (Importance: 3)
# - real time tracking (Importance: 3)
# - clear labeling (Importance: 3)
# - frequent update (Importance: 3)
# - gaining trust (Importance: 3)
# - clear navigation (Importance: 3)
# - comprehensive layout (Importance: 3)
# - improvement opportunity (Importance: 3)
# - client manager (Importance: 3)
# - contact information (Importance: 3)
# - insight (Importance: 3)
# - friendly approach (Importance: 3)
# - ai spam detection (Importance: 3)
# - proactive suggestion (Importance: 3)
# - best onboarding experience (Importance: 3)
# - open forum (Importance: 2)
# - goal achievement (Importance: 2)
# - recommend (Importance: 2)
# - revenue (Importance: 2)
# - refer friend (Importance: 2)
# - platform (Importance: 2)
# - continuously improve (Importance: 2)
# - provided template (Importance: 2)
# - engineered success (Importance: 2)
# - software (Importance: 2)
# - automatic followup (Importance: 2)
# - microsoft dynamic (Importance: 2)
# - website (Importance: 2)
# - credibility (Importance: 2)
# - close business (Importance: 2)
# - gdpr compliant (Importance: 2)
# - google workspace (Importance: 2)
# - industry expertise (Importance: 2)
# - friendly (Importance: 2)
# - showcasing value (Importance: 2)
# - hold accountable (Importance: 2)
# - document sharing (Importance: 2)
# - question assistance (Importance: 2)
# - product focus (Importance: 2)
# - marketplace relevancy (Importance: 2)
# - usability (Importance: 2)
# - content (Importance: 2)
# - opportunity (Importance: 2)
# - search console (Importance: 2)
# - audience overlap (Importance: 2)
# - award badge (Importance: 2)
# - backend option (Importance: 2)
# - costeffective (Importance: 2)
# - large database (Importance: 2)
# - affordable (Importance: 2)
# - reliable (Importance: 2)
# - flexible deployment (Importance: 2)
# - versatile application (Importance: 2)
# - thorough answer (Importance: 2)
# - transparency (Importance: 2)
# - accountability (Importance: 2)
# - productive dialogue (Importance: 2)
# - learning peer (Importance: 2)
# - community engagement (Importance: 2)
# - constructive criticism (Importance: 2)
# - hide nothing (Importance: 2)
# - vendor (Importance: 2)
# - host asset (Importance: 2)
# - branding (Importance: 2)
# - edit widget (Importance: 2)
# - form builder (Importance: 2)
# - referral program (Importance: 2)
# - effective campaigning (Importance: 2)
# - respond globally (Importance: 2)
# - educational resource (Importance: 2)
# - position (Importance: 1)
# - optimization (Importance: 1)
# - innovation (Importance: 1)
# - hard (Importance: 1)
# - charm (Importance: 1)
# - build (Importance: 1)
# - outreach (Importance: 1)
# - advocate (Importance: 1)
# - development (Importance: 1)
# - personality (Importance: 1)
# - sure (Importance: 1)
# - collaborative (Importance: 1)
# - intuitiveness (Importance: 1)
# - prospect (Importance: 1)
# - collaboration (Importance: 1)
# - clean (Importance: 1)
# - slack (Importance: 1)
# - gmail (Importance: 1)
# - android (Importance: 1)
# - hubspot (Importance: 1)
# - coding (Importance: 1)
# - seo (Importance: 1)
# - responsive (Importance: 1)
# - knowledgeable (Importance: 1)
# - dashboard (Importance: 1)
# - chart (Importance: 1)
# - demographic (Importance: 1)
# - transaction (Importance: 1)
# - registration (Importance: 1)
# - investor (Importance: 1)
# - timesaving (Importance: 1)
# - informative (Importance: 1)
# - communitydriven (Importance: 1)
# - secure (Importance: 1)
# - dispatching (Importance: 1)
# - successoriented (Importance: 1)
# - engaging (Importance: 1)
# - differentiation (Importance: 1)
# - scalable (Importance: 1)
# - researching (Importance: 1)
# - greatresource (Importance: 1)
# - emailmarketing (Importance: 1)
# - prospectivecustomers (Importance: 1)
# - emergencynotificationsoftware (Importance: 1)
# - inclusivity (Importance: 1)
# - straightforward (Importance: 1)
# - calendar (Importance: 1)
# - responsivecsms (Importance: 1)
# - trafficawareness (Importance: 1)
# - trustbuilding (Importance: 1)
# - comparing (Importance: 1)
# - company (Importance: 1)
# - supportive (Importance: 1)
# - cloudbased (Importance: 1)
# - esignatures (Importance: 1)
# -  (Importance: 0)
#
# Cluster 28:
# - efficient team management (Importance: 18)
# - task management (Importance: 17)
# - team management (Importance: 17)
# - contact management (Importance: 17)
# - account management (Importance: 17)
# - lead management (Importance: 16)
# - sale management (Importance: 16)
# - project management (Importance: 16)
# - ticket management (Importance: 16)
# - campaign management (Importance: 16)
# - user management (Importance: 16)
# - document management (Importance: 16)
#
# Cluster 42:
# - social medium integration (Importance: 14)
# - quick integration (Importance: 13)
# - integration capability (Importance: 13)
# - crm integration (Importance: 13)
# - seamless integration (Importance: 13)
# - thirdparty integration (Importance: 13)
# - integration option (Importance: 13)
# - live integration (Importance: 13)
# - integration specialist (Importance: 13)
# - integration (Importance: 12)
#
# Cluster 43:
# - easy navigate (Importance: 13)
# - easy invitation process (Importance: 13)
# - easy campaign (Importance: 12)
# - easy navigation (Importance: 12)
# - easy implementation (Importance: 12)
# - easy use (Importance: 12)
# - easy access (Importance: 12)
# - easy life (Importance: 12)
# - easy integration (Importance: 12)
# - easy (Importance: 11)
#
# Cluster 35:
# - customer feedback (Importance: 13)
# - customer requirement understanding (Importance: 13)
# - trustworthy customer input (Importance: 13)
# - customer review (Importance: 13)
# - customer advocacy promotion (Importance: 13)
# - customer success (Importance: 12)
# - new customer (Importance: 12)
# - potential customer (Importance: 12)
# - customer (Importance: 11)
#
# Cluster 4:
# - feature lead management (Importance: 14)
# - feature user review (Importance: 13)
# - feature market presence (Importance: 13)
# - feature lead (Importance: 13)
# - feature integration (Importance: 12)
# - extensive feature (Importance: 12)
# - reporting feature (Importance: 12)
# - feature analytics (Importance: 12)
# - feature (Importance: 11)
#
# Cluster 10:
# - easy contact support (Importance: 12)
# - email support (Importance: 11)
# - outstanding support (Importance: 11)
# - topnotch support (Importance: 11)
# - thorough support (Importance: 11)
# - support report (Importance: 11)
# - multilanguage support (Importance: 11)
# - comprehensive support (Importance: 11)
# - support (Importance: 10)
#
# Cluster 21:
# - user success story (Importance: 11)
# - user level access (Importance: 11)
# - user segmentation (Importance: 11)
# - clean user interface (Importance: 11)
# - explore user (Importance: 10)
# - user friendly (Importance: 10)
# - user interaction (Importance: 10)
# - verified user (Importance: 10)
#
# Cluster 5:
# - customizable branding (Importance: 13)
# - customizable view (Importance: 12)
# - customizable dashboard (Importance: 12)
# - customizable template (Importance: 12)
# - customizable field (Importance: 12)
# - customizable form (Importance: 12)
# - customizable (Importance: 11)
#
# Cluster 20:
# - reporting analytics (Importance: 14)
# - realtime analytics (Importance: 11)
# - google analytics (Importance: 9)
# - report analytics (Importance: 9)
# - analytics (Importance: 8)
# - usage reporting (Importance: 7)
# - comprehensive reporting (Importance: 7)
# - extensive reporting (Importance: 7)
# - reporting (Importance: 6)
#
# Cluster 25:
# - marketing tool (Importance: 10)
# - effective communication tool (Importance: 9)
# - vendor promotion tool (Importance: 9)
# - listing tool (Importance: 8)
# - widget tool (Importance: 8)
# - robust tool (Importance: 8)
# - seo tool (Importance: 8)
# - marketing resource (Importance: 4)
# - marketing (Importance: 3)
#
# Cluster 16:
# - data security (Importance: 11)
# - realtime data (Importance: 8)
# - data visualization (Importance: 8)
# - export data (Importance: 8)
# - data protection (Importance: 8)
# - data validation (Importance: 8)
# - data (Importance: 7)
# - robust security (Importance: 5)
# - security (Importance: 4)
#
# Cluster 11:
# - quick feedback collection (Importance: 10)
# - genuine feedback (Importance: 10)
# - opening feedback (Importance: 9)
# - harness feedback (Importance: 9)
# - lengthy feedback (Importance: 9)
# - instant feedback (Importance: 9)
# - feedback (Importance: 8)
#
# Cluster 17:
# - flexible customer support (Importance: 15)
# - personalized customer support (Importance: 15)
# - strong customer support (Importance: 15)
# - customer support (Importance: 14)
#
# Cluster 18:
# - user interface intuitive (Importance: 14)
# - intuitive interface (Importance: 13)
# - preferred interface (Importance: 8)
# - simple interface (Importance: 8)
# - intuitive design (Importance: 7)
#
# Cluster 44:
# - quick response time (Importance: 11)
# - response time (Importance: 8)
# - prompt response (Importance: 7)
# - automate response template (Importance: 7)
# - quick loading interface (Importance: 5)
# - time consuming (Importance: 4)
# - quick (Importance: 3)
#
# Cluster 8:
# - feature mobile access (Importance: 14)
# - mobile access (Importance: 13)
# - mobile app (Importance: 9)
# - quick access (Importance: 7)
#
# Cluster 37:
# - rapid campaign result (Importance: 9)
# - automated email campaign (Importance: 7)
# - link result (Importance: 6)
# - successful marketing campaign (Importance: 6)
# - email campaign (Importance: 6)
# - quick result (Importance: 5)
#
# Cluster 19:
# - professional service (Importance: 8)
# - endtoend service (Importance: 7)
# - great service (Importance: 7)
# - service report (Importance: 7)
# - impeccable service (Importance: 7)
#
# Cluster 29:
# - comparison grid (Importance: 8)
# - competitive comparison report (Importance: 7)
# - sidebyside comparison (Importance: 6)
# - grid report (Importance: 6)
# - useful grid (Importance: 5)
# - grid (Importance: 4)
#
# Cluster 12:
# - great user experience (Importance: 11)
# - streamlined user experience (Importance: 11)
# - user experience (Importance: 10)
#
# Cluster 33:
# - market profile (Importance: 6)
# - profile assistance (Importance: 6)
# - genuine profile (Importance: 6)
# - branded profile (Importance: 6)
# - profile update (Importance: 6)
#
# Cluster 23:
# - available team (Importance: 6)
# - dedicated team (Importance: 6)
# - responsive team (Importance: 6)
# - supportive team (Importance: 6)
# - personable team (Importance: 6)
#
# Cluster 34:
# - smooth onboarding process (Importance: 7)
# - process implementation (Importance: 6)
# - smooth process (Importance: 6)
# - automate process (Importance: 5)
# - implementation specialist (Importance: 3)
#
# Cluster 15:
# - efficient data visualization (Importance: 6)
# - efficient communication (Importance: 6)
# - efficient outreach (Importance: 5)
# - efficient (Importance: 4)
# - email communication (Importance: 3)
#
# Cluster 27:
# - improve online reputation (Importance: 7)
# - online business (Importance: 6)
# - online promotion (Importance: 6)
# - online (Importance: 5)
#
# Cluster 39:
# - feature sale forecasting (Importance: 7)
# - sale forecasting (Importance: 6)
# - sale resource (Importance: 5)
# - sale enablement (Importance: 5)
#
# Cluster 40:
# - decent customer service (Importance: 7)
# - great customer service (Importance: 7)
# - excellent customer service (Importance: 7)
#
# Cluster 38:
# - extensive knowledge base (Importance: 7)
# - extensive user base (Importance: 6)
# - knowledge base (Importance: 5)
#
# Cluster 26:
# - helpful team (Importance: 7)
# - helpful setup (Importance: 6)
# - helpful (Importance: 5)
#
# Cluster 22:
# - keywords sale lead (Importance: 6)
# - lead generation (Importance: 6)
# - okay lead (Importance: 5)
#
# Cluster 24:
# - initial setup (Importance: 6)
# - getting setup (Importance: 5)
# - seamless setup (Importance: 5)
#
# Cluster 3:
# - easy setup (Importance: 14)
#
# Cluster 30:
# - userfriendly interface (Importance: 14)
#
# Cluster 2:
# - userfriendly design (Importance: 7)
# - userfriendly (Importance: 5)
#
# Cluster 31:
# - automated organization (Importance: 4)
# - automated response (Importance: 3)
# - organization (Importance: 2)
#
# Cluster 41:
# - workflow automation (Importance: 5)
# - automate workflow (Importance: 4)
#
# Cluster 32:
# - ab testing (Importance: 5)
# - ab (Importance: 3)
#
# Cluster 36:
# - easytouse platform (Importance: 4)
# - easytouse (Importance: 3)
#
# Cluster 13:
# - scalability (Importance: 5)
#
# Cluster 9:
# - marketing automation integration (Importance: 3)
#
# Cluster 6:
# - feature customer support (Importance: 3)
#
# Cluster 7:
# - customer relationship management (Importance: 3)
#
# Cluster 14:
# - easy organization (Importance: 2)

# %%
# Pick top 2 features from each cluster
top_features_per_cluster = {}

for cluster_id, cluster_features in clusters.items():
    sorted_features = sorted(cluster_features, key=lambda x: x["importance"], reverse=True)
    top_features_per_cluster[cluster_id] = sorted_features[:2]

# Print top 2 features from each cluster
for cluster_id, top_features in top_features_per_cluster.items():
    print(f"Cluster {cluster_id}:")
    for feature in top_features:
        print(f"- {feature['feature']} (Importance: {feature['importance']})")
    print()
# Out:
# Cluster 1:
# - benefit benefit (Importance: 8)
# - simple pricing (Importance: 7)
#
# Cluster 33:
# - market profile (Importance: 6)
# - profile assistance (Importance: 6)
#
# Cluster 8:
# - feature mobile access (Importance: 14)
# - mobile access (Importance: 13)
#
# Cluster 28:
# - efficient team management (Importance: 18)
# - task management (Importance: 17)
#
# Cluster 39:
# - feature sale forecasting (Importance: 7)
# - sale forecasting (Importance: 6)
#
# Cluster 15:
# - efficient data visualization (Importance: 6)
# - efficient communication (Importance: 6)
#
# Cluster 9:
# - marketing automation integration (Importance: 3)
#
# Cluster 21:
# - user success story (Importance: 11)
# - user level access (Importance: 11)
#
# Cluster 19:
# - professional service (Importance: 8)
# - endtoend service (Importance: 7)
#
# Cluster 0:
# - automated review process (Importance: 29)
# - organizationlike review process (Importance: 28)
#
# Cluster 34:
# - smooth onboarding process (Importance: 7)
# - process implementation (Importance: 6)
#
# Cluster 23:
# - available team (Importance: 6)
# - dedicated team (Importance: 6)
#
# Cluster 31:
# - automated organization (Importance: 4)
# - automated response (Importance: 3)
#
# Cluster 10:
# - easy contact support (Importance: 12)
# - email support (Importance: 11)
#
# Cluster 24:
# - initial setup (Importance: 6)
# - getting setup (Importance: 5)
#
# Cluster 44:
# - quick response time (Importance: 11)
# - response time (Importance: 8)
#
# Cluster 27:
# - improve online reputation (Importance: 7)
# - online business (Importance: 6)
#
# Cluster 37:
# - rapid campaign result (Importance: 9)
# - automated email campaign (Importance: 7)
#
# Cluster 42:
# - social medium integration (Importance: 14)
# - quick integration (Importance: 13)
#
# Cluster 12:
# - great user experience (Importance: 11)
# - streamlined user experience (Importance: 11)
#
# Cluster 38:
# - extensive knowledge base (Importance: 7)
# - extensive user base (Importance: 6)
#
# Cluster 35:
# - customer feedback (Importance: 13)
# - customer requirement understanding (Importance: 13)
#
# Cluster 20:
# - reporting analytics (Importance: 14)
# - realtime analytics (Importance: 11)
#
# Cluster 5:
# - customizable branding (Importance: 13)
# - customizable view (Importance: 12)
#
# Cluster 4:
# - feature lead management (Importance: 14)
# - feature user review (Importance: 13)
#
# Cluster 26:
# - helpful team (Importance: 7)
# - helpful setup (Importance: 6)
#
# Cluster 14:
# - easy organization (Importance: 2)
#
# Cluster 11:
# - quick feedback collection (Importance: 10)
# - genuine feedback (Importance: 10)
#
# Cluster 25:
# - marketing tool (Importance: 10)
# - effective communication tool (Importance: 9)
#
# Cluster 32:
# - ab testing (Importance: 5)
# - ab (Importance: 3)
#
# Cluster 3:
# - easy setup (Importance: 14)
#
# Cluster 17:
# - flexible customer support (Importance: 15)
# - personalized customer support (Importance: 15)
#
# Cluster 30:
# - userfriendly interface (Importance: 14)
#
# Cluster 16:
# - data security (Importance: 11)
# - realtime data (Importance: 8)
#
# Cluster 2:
# - userfriendly design (Importance: 7)
# - userfriendly (Importance: 5)
#
# Cluster 29:
# - comparison grid (Importance: 8)
# - competitive comparison report (Importance: 7)
#
# Cluster 18:
# - user interface intuitive (Importance: 14)
# - intuitive interface (Importance: 13)
#
# Cluster 43:
# - easy navigate (Importance: 13)
# - easy invitation process (Importance: 13)
#
# Cluster 22:
# - keywords sale lead (Importance: 6)
# - lead generation (Importance: 6)
#
# Cluster 40:
# - decent customer service (Importance: 7)
# - great customer service (Importance: 7)
#
# Cluster 6:
# - feature customer support (Importance: 3)
#
# Cluster 13:
# - scalability (Importance: 5)
#
# Cluster 41:
# - workflow automation (Importance: 5)
# - automate workflow (Importance: 4)
#
# Cluster 7:
# - customer relationship management (Importance: 3)
#
# Cluster 36:
# - easytouse platform (Importance: 4)
# - easytouse (Importance: 3)

# %%
# Create a list of all top features from each cluster
all_top_features = [feature for  top_features in top_features_per_cluster.values() for feature in top_features]

# Sort the list of top features based on importance scores
all_top_features.sort(key=lambda x: x['importance'], reverse=True)

# Print the sorted list of top features
for feature in all_top_features:
    print(f"- {feature['feature']}")
# Out:
# - automated review process
# - organizationlike review process
# - efficient team management
# - task management
# - flexible customer support
# - personalized customer support
# - feature mobile access
# - social medium integration
# - reporting analytics
# - feature lead management
# - easy setup
# - userfriendly interface
# - user interface intuitive
# - mobile access
# - quick integration
# - customer feedback
# - customer requirement understanding
# - customizable branding
# - feature user review
# - intuitive interface
# - easy navigate
# - easy invitation process
# - easy contact support
# - customizable view
# - user success story
# - user level access
# - email support
# - quick response time
# - great user experience
# - streamlined user experience
# - realtime analytics
# - data security
# - quick feedback collection
# - genuine feedback
# - marketing tool
# - rapid campaign result
# - effective communication tool
# - benefit benefit
# - professional service
# - response time
# - realtime data
# - comparison grid
# - simple pricing
# - feature sale forecasting
# - endtoend service
# - smooth onboarding process
# - improve online reputation
# - automated email campaign
# - extensive knowledge base
# - helpful team
# - userfriendly design
# - competitive comparison report
# - decent customer service
# - great customer service
# - market profile
# - profile assistance
# - sale forecasting
# - efficient data visualization
# - efficient communication
# - process implementation
# - available team
# - dedicated team
# - initial setup
# - online business
# - extensive user base
# - helpful setup
# - keywords sale lead
# - lead generation
# - getting setup
# - ab testing
# - userfriendly
# - scalability
# - workflow automation
# - automated organization
# - automate workflow
# - easytouse platform
# - marketing automation integration
# - automated response
# - ab
# - feature customer support
# - customer relationship management
# - easytouse
# - easy organization
